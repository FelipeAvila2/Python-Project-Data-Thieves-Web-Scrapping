# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

# %%
def Auchan_funct():
    url = 'https://www.auchan.pt/pt/beleza-higiene-e-bebe/' # the url for the lidl baby products
    k = requests.get(url).text # the response
    
    soup = BeautifulSoup(k,'html.parser') # use the beautifulsoup to parse the html
    price_list_raw = soup.find_all('div',class_='auc-product-tile__prices') # get the raw list of the prices
    
    price_list = [] # the clean list of prices
    
    for element in price_list_raw:
        price_list.append((element.text).replace('\n','').strip()) # for loop to clean each item in the raw list
    
    
    soup = BeautifulSoup(k,'html.parser') # use beautifulsoup to parse the html
    name_list_raw = soup.find_all('div', class_="auc-product-tile__name") # the raw list of items names
    
    name_list = [] # the clean list of prices

    for element in name_list_raw: 
        name_list.append((element.text).replace('\n','').strip()) # the for loop for cleaning each item in the raw list
        
    new_dict = {
        'produtos': name_list,
        'preços': price_list,
        'supermercado': 'Auchan'
    } # the dict that is going to get changed into a dataframe
    
    return pd.DataFrame(new_dict) #name_list,#price_list#price_list_raw#price_list #the return with a dataframe

# %%
Auchan1 = Auchan_funct()

# %%
Auchan1
# Out:
#                                              produtos  \
# 0               lenços de papel renova essential 6 un
# 1     sabonete dettol líquido aloé vera recarga 250ml
# 2      pensos higiénicos evax liberty noite alas 9 un
# 3   pasta dentífrica colgate total advanced hálit ...
# 4     protector evax diário salva slip adaptador 30un
# 5        pasta dentífrica auchan kids 2+ morango 50ml
# 6               sabonete dove shea butter pack 4x100g
# 7             deo spray rexona mulher biorythm 150ml.
# 8       pasta dentífrica colgate total original 75 ml
# 9   pasta dentífrica theramed 2 em 1 branqueadora ...
# 10     sabonete cosmia exfoliante com alperce 90g 1un
# 11                         deo spray axe apollo 150ml
# 12        papel higiénico scottex spa sensation 66 un
# 13  sabonete cosmia líquido recarga frutos vermelh...
# 14       papel higiénico scottex húmido recarga 40 un
# 15        pasta dentífrica colgate herbal white 75 ml
# 16          água cosmia baby perfumada frescura 100ml
# 17              toalhitas renova mãos com álcool 20un
# 18  amaciador cosmia technique repair + proteína t...
# 19  pasta dentífrica colgate total advanced limp p...
# 20  pasta dentífrica golden silk vegan argila e fu...
# 21                 máscara elvive total repair 300 ml
# 22                pasta dentífrica auchan herbal 75ml
# 23            escova dentes auchan clássica média 3un
#
#                               preços supermercado
# 0                             0,79 €       Auchan
# 1                             3,09 €       Auchan
# 2                             2,99 €       Auchan
# 3                             3,99 €       Auchan
# 4                             2,56 €       Auchan
# 5                             0,67 €       Auchan
# 6                             4,84 €       Auchan
# 7                             3,48 €       Auchan
# 8                             3,19 €       Auchan
# 9                             2,99 €       Auchan
# 10                            0,69 €       Auchan
# 11  Price reduced from4,68 €to2,79 €       Auchan
# 12  Price reduced from2,70 €to2,09 €       Auchan
# 13                            0,89 €       Auchan
# 14                            1,64 €       Auchan
# 15  Price reduced from2,12 €to1,64 €       Auchan
# 16                            2,08 €       Auchan
# 17                            1,55 €       Auchan
# 18  Price reduced from1,75 €to0,99 €       Auchan
# 19                            3,99 €       Auchan
# 20                            2,59 €       Auchan
# 21                            6,78 €       Auchan
# 22                            0,79 €       Auchan
# 23                            0,96 €       Auchan

# %%
def Auchan_link2_funct():
    url = 'https://www.auchan.pt/pt/beleza-higiene-e-bebe/fraldas-e-toalhitas-de-bebe/' # the url for the lidl baby products
    k = requests.get(url).text # the response
    
    soup = BeautifulSoup(k,'html.parser') # use the beautifulsoup to parse the html
    price_list_raw = soup.find_all('div',class_='auc-product-tile__prices') # get the raw list of the prices
    
    price_list = [] # the clean list of prices
    
    for element in price_list_raw:
        price_list.append((element.text).replace('\n','').strip()) # for loop to clean each item in the raw list
    
    
    soup = BeautifulSoup(k,'html.parser') # use beautifulsoup to parse the html
    name_list_raw = soup.find_all('div', class_="auc-product-tile__name") # the raw list of items names
    
    name_list = [] # the clean list of prices

    for element in name_list_raw: 
        name_list.append((element.text).replace('\n','').strip()) # the for loop for cleaning each item in the raw list
        
    new_dict = {
        'produtos': name_list,
        'preços': price_list,
        'supermercado': 'Auchan'
    } # the dict that is going to get changed into a dataframe
    
    return pd.DataFrame(new_dict) #name_list,#price_list#price_list_raw#price_list #the return with a dataframe

# %%
Auchan_link2_funct()
# Out:
#                                              produtos  \
# 0           água cosmia baby perfumada frescura 100ml
# 1                  fraldas auchan baby t4 7-18kg 48un
# 2                       toalhitas dodot mainline 64un
# 3                 fraldas auchan baby t5 11-25kg 44un
# 4                toalhitas corine de farme rosto 25un
# 5                         toalhitas dodot básico 54un
# 6                    toalhitas dodot mãos limpas 40un
# 7              toalhitas huggies natural care 4x56 un
# 8   toalhitas cosmia baby com água limpeza (3x64)1...
# 9                       toalhitas huggies hands 56 un
# 10             toalhitas criança kandoo melão 2x60 un
# 11               toalhitas auchan essencial bebé 70un
# 12      toalhitas cosmia baby com tampa camomila 56un
# 13   toalhitas criança kandoo frutos da selva 2x50 un
# 14                     toalhitas nunex basic sd 72 un
# 15              toalhitas huggies natural care 168 un
# 16    toalhitas cosmia baby com tampa com azeite 64un
# 17     toalhitas cosmia baby com água de limpeza 64un
# 18               toalhitas huggies natural care 56 un
# 19                fraldas auchan baby t6 13-27kg 40un
# 20               fraldas auchan baby t5 11-25kg 136un
# 21             creme corine de farme hidratante 500ml
# 22  leite hidrat. corine de farme peles sensiveis ...
# 23         fraldas dodot azul bebé seco t6 13+kg 48un
#
#                                preços supermercado
# 0                              2,08 €       Auchan
# 1                              5,99 €       Auchan
# 2    Price reduced from1,34 €to0,99 €       Auchan
# 3                              5,99 €       Auchan
# 4                              2,12 €       Auchan
# 5                              0,99 €       Auchan
# 6                              1,39 €       Auchan
# 7    Price reduced from7,75 €to3,98 €       Auchan
# 8                              3,22 €       Auchan
# 9                              0,96 €       Auchan
# 10                             4,99 €       Auchan
# 11                             0,87 €       Auchan
# 12                             0,86 €       Auchan
# 13                             3,29 €       Auchan
# 14                             0,79 €       Auchan
# 15                             3,87 €       Auchan
# 16                             1,04 €       Auchan
# 17                             0,86 €       Auchan
# 18   Price reduced from1,93 €to1,00 €       Auchan
# 19                             5,99 €       Auchan
# 20                            19,90 €       Auchan
# 21                             6,98 €       Auchan
# 22                             5,99 €       Auchan
# 23  Price reduced from13,49 €to9,99 €       Auchan
