# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

# %%
def Auchan_funct():
    url = 'https://www.auchan.pt/pt/beleza-higiene-e-bebe/' # the url for the lidl baby products
    k = requests.get(url).text # the response
    
    soup = BeautifulSoup(k,'html.parser') # use the beautifulsoup to parse the html
    price_list_raw = soup.find_all('div', class_="auc-product-tile__name") # get the raw list of the prices
    
    price_list = [] # the clean list of prices
    
    for element in price_list_raw:
        price_list.append((element.text).replace('\n','').strip()) # for loop to clean each item in the raw list
    
    
    soup = BeautifulSoup(k,'html.parser') # use beautifulsoup to parse the html
    name_list_raw = soup.find_all('div',class_='auc-product-tile__prices') # the raw list of items names
    
    name_list = [] # the clean list of prices

    for element in name_list_raw: 
        name_list.append((element.text).replace('\n','').strip()) # the for loop for cleaning each item in the raw list
        
    new_dict = {
        'produtos': name_list,
        'preços': price_list,
        'supermercado': 'Auchan'
    } # the dict that is going to get changed into a dataframe
    
    return pd.DataFrame(new_dict) #name_list,#price_list#price_list_raw#price_list #the return with a dataframe

# %%
Auchan1 = Auchan_funct()

# %%
Auchan1
# Out:
#                             produtos  \
# 0                             0,79 €
# 1                             3,09 €
# 2                             2,99 €
# 3                             3,99 €
# 4                             2,56 €
# 5                             0,67 €
# 6                             4,84 €
# 7                             3,48 €
# 8                             3,19 €
# 9                             2,99 €
# 10                            0,69 €
# 11  Price reduced from4,68 €to2,79 €
# 12  Price reduced from2,70 €to2,09 €
# 13                            0,89 €
# 14                            1,64 €
# 15  Price reduced from2,12 €to1,64 €
# 16                            2,08 €
# 17                            1,55 €
# 18  Price reduced from1,75 €to0,99 €
# 19                            3,99 €
# 20                            2,59 €
# 21                            6,78 €
# 22                            0,79 €
# 23                            0,96 €
#
#                                                preços supermercado
# 0               lenços de papel renova essential 6 un         lidl
# 1     sabonete dettol líquido aloé vera recarga 250ml         lidl
# 2      pensos higiénicos evax liberty noite alas 9 un         lidl
# 3   pasta dentífrica colgate total advanced hálit ...         lidl
# 4     protector evax diário salva slip adaptador 30un         lidl
# 5        pasta dentífrica auchan kids 2+ morango 50ml         lidl
# 6               sabonete dove shea butter pack 4x100g         lidl
# 7             deo spray rexona mulher biorythm 150ml.         lidl
# 8       pasta dentífrica colgate total original 75 ml         lidl
# 9   pasta dentífrica theramed 2 em 1 branqueadora ...         lidl
# 10     sabonete cosmia exfoliante com alperce 90g 1un         lidl
# 11                         deo spray axe apollo 150ml         lidl
# 12        papel higiénico scottex spa sensation 66 un         lidl
# 13  sabonete cosmia líquido recarga frutos vermelh...         lidl
# 14       papel higiénico scottex húmido recarga 40 un         lidl
# 15        pasta dentífrica colgate herbal white 75 ml         lidl
# 16          água cosmia baby perfumada frescura 100ml         lidl
# 17              toalhitas renova mãos com álcool 20un         lidl
# 18  amaciador cosmia technique repair + proteína t...         lidl
# 19  pasta dentífrica colgate total advanced limp p...         lidl
# 20  pasta dentífrica golden silk vegan argila e fu...         lidl
# 21                 máscara elvive total repair 300 ml         lidl
# 22                pasta dentífrica auchan herbal 75ml         lidl
# 23            escova dentes auchan clássica média 3un         lidl
