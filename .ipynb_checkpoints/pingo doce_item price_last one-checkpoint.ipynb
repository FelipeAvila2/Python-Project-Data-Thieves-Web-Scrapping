# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

# %%
# This is the url you will scrape in this exercise
url = 'https://www.pingodoce.pt/produtos/marca-propria-pingo-doce/cuida-bebe/fraldas-activity-extra-care-t3-4-10kg-pingo-doce-cuida-bebe-56-unid/'

# %%
def pingo_funct():
    #url = 'https://www.pingodoce.pt/produtos/marca-propria-pingo-doce/cuida-bebe/'# the url for the lidl baby products
    url='https://www.pingodoce.pt/produtos/marca-propria-pingo-doce/cuida-bebe/fraldas-activity-extra-care-t3-4-10kg-pingo-doce-cuida-bebe-56-unid/'
    k = requests.get(url).text # the response
    
    soup=BeautifulSoup(k,'html.parser') # use the beautifulsoup to parse the html
    price_list_raw = soup.find_all('span', attrs= { 'class:','product-cards_price'}) # get the raw list of the prices
    
    #<span class="product-cards_price">2,99€ / UN</span>
      
    price_list = [] # the clean list of prices
    
    for element in price_list_raw:
        price_list.append((element.text).replace('/ UN','').strip()) # for loop to clean each item in the raw list
    
    
    soup = BeautifulSoup(k,'html.parser') # use beautifulsoup to parse the html
    name_list_raw = soup.find_all('h3', attrs= { 'class:','product-cards__title'}) # the raw list of items names
    
    name_list = [] # the clean list of prices

    for element in name_list_raw: 
        name_list.append((element.text).replace('\n','').strip()) # the for loop for cleaning each item in the raw list
        
    new_dict = {
        'produtos': name_list,
        'preços': price_list,
        'supermercado': 'pingo doce'
    } # the dict that is going to get changed into a dataframe
    
    return name_list,price_list#,pd.DataFrame(new_dict) # the return with a dataframe

# %%
pingo_funct()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-6b276e5fec01> in <module>
# ----> 1 pingo_funct()
#
# <ipython-input-1-91050027e181> in pingo_funct()
#       2     #url = 'https://www.pingodoce.pt/produtos/marca-propria-pingo-doce/cuida-bebe/'# the url for the lidl baby products
#       3     url='https://www.pingodoce.pt/produtos/marca-propria-pingo-doce/cuida-bebe/fraldas-activity-extra-care-t3-4-10kg-pingo-doce-cuida-bebe-56-unid/'
# ----> 4     k = requests.get(url).text # the response
#       5
#       6     soup=BeautifulSoup(k,'html.parser') # use the beautifulsoup to parse the html
#
# NameError: name 'requests' is not defined

# %% [markdown]
# ##                                          Testar o código com outro url

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

def pingo_funct():
    url = 'https://www.pingodoce.pt/produtos/marca-propria-pingo-doce/cuida-bebe/'# the url for the lidl baby products
    #url='https://www.pingodoce.pt/produtos/marca-propria-pingo-doce/cuida-bebe/fraldas-activity-extra-care-t3-4-10kg-pingo-doce-cuida-bebe-56-unid/'
    k = requests.get(url).text # the response
    
    soup=BeautifulSoup(k,'html.parser') # use the beautifulsoup to parse the html
    price_list_raw = soup.find_all('span', attrs = ('class:','product-cards_price') ) # get the raw list of the prices
    
    #<span class="product-cards_price">2,99€ / UN</span>
      
    price_list = [] # the clean list of prices
    
    for element in price_list_raw:
        price_list.append((element.text).replace(',','.').replace('\n','').strip()) # for loop to clean each item in the raw list
    
    
    soup = BeautifulSoup(k,'html.parser') # use beautifulsoup to parse the html
    name_list_raw = soup.find_all('h3', attrs= {'class:','product-cards__title'}) # the raw list of items names
    
    name_list = [] # the clean list of prices

    for element in name_list_raw: 
        name_list.append((element.text).replace('\n','').strip()) # the for loop for cleaning each item in the raw list
        
    new_dict = {
        'produtos': name_list,
        'preços': price_list,
        'supermercado': 'pingo doce'
    } # the dict that is going to get changed into a dataframe
    
    return pd.DataFrame(new_dict) # the return with a dataframe

# %%
pingo_funct()
# Out:
# Empty DataFrame
# Columns: [produtos, preços, supermercado]
# Index: []

# %%
    url = 'https://www.pingodoce.pt/produtos/marca-propria-pingo-doce/cuida-bebe/'# the url for the lidl baby products
    #url='https://www.pingodoce.pt/produtos/marca-propria-pingo-doce/cuida-bebe/fraldas-activity-extra-care-t3-4-10kg-pingo-doce-cuida-bebe-56-unid/'
    k = requests.get(url).text # the response
    soup=BeautifulSoup(k,'html.parser') # use the beautifulsoup to parse the html
    price_list_raw = soup.find_all('div')

# %%
price_list_raw
# Out:
# [<div class="main-header">
#  <div class="container">
#  <div class="left-area">
#  <div class="top-bar">
#  <a href="/sobre-nos/">Sobre Nós</a>
#  <a href="/responsabilidade/">Responsabilidade</a>
#  <a href="/junte-se-a-nos/">Junte-se a nós</a>
#  </div> <div class="bottom-bar">
#  <div class="menu">
#  <a href="/produtos/">Produtos</a>
#  <a href="/receitas/">Receitas</a>
#  <a href="/folhetos/">Folhetos</a>
#  </div> </div>
#  </div>
#  <div class="center-area"><a href="/"><img alt="Pingo Doce" class="js-lazy-load" data-src="/wp-content/themes/pingodoce/library/images/v2/supermercados-pingo-doce.png" height="43" src="..." width="161"/></a></div>
#  <div class="right-area">
#  <div class="top-bar">
#  <a class="food" data-gaevent="Clique|Take Away|Botao TA header" href="/produtos/take-away/encomendas/"><img alt="Comprar online" class="js-lazy-load" data-src="/wp-content/themes/pingodoce/library/images/v2/header-food.svg" height="24" src="..." width="24"/>Encomendar comida</a>
#  <a class="cart" data-gaevent="Clique|Mercadao|Botao mercadao" href="https://mercadao.pt/store/pingo-doce?utm_source=pingo-doce&amp;utm_medium=botao-comprar-online&amp;utm_campaign=referencia-pingo-doce" rel="noopener" target="_blank"><img alt="Comprar online" class="js-lazy-load" data-src="/wp-content/themes/pingodoce/library/images/v2/header-cart.svg" height="24" src="..." width="24"/>Comprar online</a>
#  <a class="pm" href="/sobre-nos/cartao-poupa-mais/"><img alt="Poupa Mais" class="js-lazy-load" data-src="/wp-content/themes/pingodoce/library/images/v2/header-poupamais.png" height="18" src="..." width="28"/>Poupa Mais</a>
#  </div>
#  <div class="bottom-bar">
#  <div class="menu">
#  <div class="menu">
#  <a href="/lojas/">Lojas</a>
#  <a href="/apoio-ao-cliente/">Apoio ao cliente</a>
#  </div> </div>
#  <div class="side-icons">
#  <span class="search-toggle js-toggle-search-bar">
#  <img alt="Pesquisa" class="search" height="24" src="/wp-content/themes/pingodoce/library/images/v2/icon-search.svg" width="24"/>
#  <img alt="Pesquisa" class="close" height="24" src="/wp-content/themes/pingodoce/library/images/v2/icon-close.svg" width="24"/>
#  </span>
#  <a href="/login/">
#  <img alt="Área de Utilizador" class="user-icon js-user-icon" height="24" src="/wp-content/themes/pingodoce/library/images/v2/icon-user.svg" width="24"/>
#  <img alt="Área de Utilizador" class="user-icon hidden js-user-icon-logged-in" height="24" src="/wp-content/themes/pingodoce/library/images/v2/icon-user.svg" width="24"/>
#  </a>
#  </div>
#  </div>
#  </div>
#  </div>
#  </div>,
#  <div class="container">
#  <div class="left-area">
#  <div class="top-bar">
#  <a href="/sobre-nos/">Sobre Nós</a>
#  <a href="/responsabilidade/">Responsabilidade</a>
#  <a href="/junte-se-a-nos/">Junte-se a nós</a>
#  </div> <div class="bottom-bar">
#  <div class="menu">
#  <a href="/produtos/">Produtos</a>
#  <a href="/receitas/">Receitas</a>
#  <a href="/folhetos/">Folhetos</a>
#  </div> </div>
#  </div>
#  <div class="center-area"><a href="/"><img alt="Pingo Doce" class="js-lazy-load" data-src="/wp-content/themes/pingodoce/library/images/v2/supermercados-pingo-doce.png" height="43" src="..." width="161"/></a></div>
#  <div class="right-area">
#  <div class="top-bar">
#  <a class="food" data-gaevent="Clique|Take Away|Botao TA header" href="/produtos/take-away/encomendas/"><img alt="Comprar online" class="js-lazy-load" data-src="/wp-content/themes/pingodoce/library/images/v2/header-food.svg" height="24" src="..." width="24"/>Encomendar comida</a>
#  <a class="cart" data-gaevent="Clique|Mercadao|Botao mercadao" href="https://mercadao.pt/store/pingo-doce?utm_source=pingo-doce&amp;utm_medium=botao-comprar-online&amp;utm_campaign=referencia-pingo-doce" rel="noopener" target="_blank"><img alt="Comprar online" class="js-lazy-load" data-src="/wp-content/themes/pingodoce/library/images/v2/header-cart.svg" height="24" src="..." width="24"/>Comprar online</a>
#  <a class="pm" href="/sobre-nos/cartao-poupa-mais/"><img alt="Poupa Mais" class="js-lazy-load" data-src="/wp-content/themes/pingodoce/library/images/v2/header-poupamais.png" height="18" src="..." width="28"/>Poupa Mais</a>
#  </div>
#  <div class="bottom-bar">
#  <div class="menu">
#  <div class="menu">
#  <a href="/lojas/">Lojas</a>
#  <a href="/apoio-ao-cliente/">Apoio ao cliente</a>
#  </div> </div>
#  <div class="side-icons">
#  <span class="search-toggle js-toggle-search-bar">
#  <img alt="Pesquisa" class="search" height="24" src="/wp-content/themes/pingodoce/library/images/v2/icon-search.svg" width="24"/>
#  <img alt="Pesquisa" class="close" height="24" src="/wp-content/themes/pingodoce/library/images/v2/icon-close.svg" width="24"/>
#  </span>
#  <a href="/login/">
#  <img alt="Área de Utilizador" class="user-icon js-user-icon" height="24" src="/wp-content/themes/pingodoce/library/images/v2/icon-user.svg" width="24"/>
#  <img alt="Área de Utilizador" class="user-icon hidden js-user-icon-logged-in" height="24" src="/wp-content/themes/pingodoce/library/images/v2/icon-user.svg" width="24"/>
#  </a>
#  </div>
#  </div>
#  </div>
#  </div>,
#  <div class="left-area">
#  <div class="top-bar">
#  <a href="/sobre-nos/">Sobre Nós</a>
#  <a href="/responsabilidade/">Responsabilidade</a>
#  <a href="/junte-se-a-nos/">Junte-se a nós</a>
#  </div> <div class="bottom-bar">
#  <div class="menu">
#  <a href="/produtos/">Produtos</a>
#  <a href="/receitas/">Receitas</a>
#  <a href="/folhetos/">Folhetos</a>
#  </div> </div>
#  </div>,
#  <div class="top-bar">
#  <a href="/sobre-nos/">Sobre Nós</a>
#  <a href="/responsabilidade/">Responsabilidade</a>
#  <a href="/junte-se-a-nos/">Junte-se a nós</a>
#  </div>,
#  <div class="bottom-bar">
#  <div class="menu">
#  <a href="/produtos/">Produtos</a>
#  <a href="/receitas/">Receitas</a>
#  <a href="/folhetos/">Folhetos</a>
#  </div> </div>,
#  <div class="menu">
#  <a href="/produtos/">Produtos</a>
#  <a href="/receitas/">Receitas</a>
#  <a href="/folhetos/">Folhetos</a>
#  </div>,
#  <div class="center-area"><a href="/"><img alt="Pingo Doce" class="js-lazy-load" data-src="/wp-content/themes/pingodoce/library/images/v2/supermercados-pingo-doce.png" height="43" src="..." width="161"/></a></div>,
#  <div class="right-area">
#  <div class="top-bar">
#  <a class="food" data-gaevent="Clique|Take Away|Botao TA header" href="/produtos/take-away/encomendas/"><img alt="Comprar online" class="js-lazy-load" data-src="/wp-content/themes/pingodoce/library/images/v2/header-food.svg" height="24" src="..." width="24"/>Encomendar comida</a>
#  <a class="cart" data-gaevent="Clique|Mercadao|Botao mercadao" href="https://mercadao.pt/store/pingo-doce?utm_source=pingo-doce&amp;utm_medium=botao-comprar-online&amp;utm_campaign=referencia-pingo-doce" rel="noopener" target="_blank"><img alt="Comprar online" class="js-lazy-load" data-src="/wp-content/themes/pingodoce/library/images/v2/header-cart.svg" height="24" src="..." width="24"/>Comprar online</a>
#  <a class="pm" href="/sobre-nos/cartao-poupa-mais/"><img alt="Poupa Mais" class="js-lazy-load" data-src="/wp-content/themes/pingodoce/library/images/v2/header-poupamais.png" height="18" src="..." width="28"/>Poupa Mais</a>
#  </div>
#  <div class="bottom-bar">
#  <div class="menu">
#  <div class="menu">
#  <a href="/lojas/">Lojas</a>
#  <a href="/apoio-ao-cliente/">Apoio ao cliente</a>
#  </div> </div>
#  <div class="side-icons">
#  <span class="search-toggle js-toggle-search-bar">
#  <img alt="Pesquisa" class="search" height="24" src="/wp-content/themes/pingodoce/library/images/v2/icon-search.svg" width="24"/>
#  <img alt="Pesquisa" class="close" height="24" src="/wp-content/themes/pingodoce/library/images/v2/icon-close.svg" width="24"/>
#  </span>
#  <a href="/login/">
#  <img alt="Área de Utilizador" class="user-icon js-user-icon" height="24" src="/wp-content/themes/pingodoce/library/images/v2/icon-user.svg" width="24"/>
#  <img alt="Área de Utilizador" class="user-icon hidden js-user-icon-logged-in" height="24" src="/wp-content/themes/pingodoce/library/images/v2/icon-user.svg" width="24"/>
#  </a>
#  </div>
#  </div>
#  </div>,
#  <div class="top-bar">
#  <a class="food" data-gaevent="Clique|Take Away|Botao TA header" href="/produtos/take-away/encomendas/"><img alt="Comprar online" class="js-lazy-load" data-src="/wp-content/themes/pingodoce/library/images/v2/header-food.svg" height="24" src="..." width="24"/>Encomendar comida</a>
#  <a class="cart" data-gaevent="Clique|Mercadao|Botao mercadao" href="https://mercadao.pt/store/pingo-doce?utm_source=pingo-doce&amp;utm_medium=botao-comprar-online&amp;utm_campaign=referencia-pingo-doce" rel="noopener" target="_blank"><img alt="Comprar online" class="js-lazy-load" data-src="/wp-content/themes/pingodoce/library/images/v2/header-cart.svg" height="24" src="..." width="24"/>Comprar online</a>
#  <a class="pm" href="/sobre-nos/cartao-poupa-mais/"><img alt="Poupa Mais" class="js-lazy-load" data-src="/wp-content/themes/pingodoce/library/images/v2/header-poupamais.png" height="18" src="..." width="28"/>Poupa Mais</a>
#  </div>,
#  <div class="bottom-bar">
#  <div class="menu">
#  <div class="menu">
#  <a href="/lojas/">Lojas</a>
#  <a href="/apoio-ao-cliente/">Apoio ao cliente</a>
#  </div> </div>
#  <div class="side-icons">
#  <span class="search-toggle js-toggle-search-bar">
#  <img alt="Pesquisa" class="search" height="24" src="/wp-content/themes/pingodoce/library/images/v2/icon-search.svg" width="24"/>
#  <img alt="Pesquisa" class="close" height="24" src="/wp-content/themes/pingodoce/library/images/v2/icon-close.svg" width="24"/>
#  </span>
#  <a href="/login/">
#  <img alt="Área de Utilizador" class="user-icon js-user-icon" height="24" src="/wp-content/themes/pingodoce/library/images/v2/icon-user.svg" width="24"/>
#  <img alt="Área de Utilizador" class="user-icon hidden js-user-icon-logged-in" height="24" src="/wp-content/themes/pingodoce/library/images/v2/icon-user.svg" width="24"/>
#  </a>
#  </div>
#  </div>,
#  <div class="menu">
#  <div class="menu">
#  <a href="/lojas/">Lojas</a>
#  <a href="/apoio-ao-cliente/">Apoio ao cliente</a>
#  </div> </div>,
#  <div class="menu">
#  <a href="/lojas/">Lojas</a>
#  <a href="/apoio-ao-cliente/">Apoio ao cliente</a>
#  </div>,
#  <div class="side-icons">
#  <span class="search-toggle js-toggle-search-bar">
#  <img alt="Pesquisa" class="search" height="24" src="/wp-content/themes/pingodoce/library/images/v2/icon-search.svg" width="24"/>
#  <img alt="Pesquisa" class="close" height="24" src="/wp-content/themes/pingodoce/library/images/v2/icon-close.svg" width="24"/>
#  </span>
#  <a href="/login/">
#  <img alt="Área de Utilizador" class="user-icon js-user-icon" height="24" src="/wp-content/themes/pingodoce/library/images/v2/icon-user.svg" width="24"/>
#  <img alt="Área de Utilizador" class="user-icon hidden js-user-icon-logged-in" height="24" src="/wp-content/themes/pingodoce/library/images/v2/icon-user.svg" width="24"/>
#  </a>
#  </div>,
#  <div class="main-header-mobile">
#  <div class="menu-icon">
#  <div class="mobile-menu-icon js-toggle-mobile-menu">
#  <div class="box">
#  <div class="inner"></div>
#  </div>
#  </div>
#  </div>
#  <a class="logo" href="/"><img alt="Pingo Doce" class="js-lazy-load" data-src="/wp-content/themes/pingodoce/library/images/v2/supermercados-pingo-doce-mobile.png" height="32" src="..." width="106"/></a>
#  <div class="side-icons">
#  <span class="search-toggle js-toggle-search-bar">
#  <img alt="Pesquisa" class="search" height="32" src="/wp-content/themes/pingodoce/library/images/v2/icon-search.svg" width="32"/>
#  <img alt="Pesquisa" class="close" height="32" src="/wp-content/themes/pingodoce/library/images/v2/icon-close.svg" width="32"/>
#  </span>
#  <a href="/login/">
#  <img alt="Área de Utilizador" class="user-icon js-user-icon" height="32" src="/wp-content/themes/pingodoce/library/images/v2/icon-user.svg" width="32"/>
#  <img alt="Área de Utilizador" class="user-icon hidden js-user-icon-logged-in" height="32" src="/wp-content/themes/pingodoce/library/images/v2/icon-user-active.svg" width="32"/>
#  </a>
#  </div>
#  </div>,
#  <div class="menu-icon">
#  <div class="mobile-menu-icon js-toggle-mobile-menu">
#  <div class="box">
#  <div class="inner"></div>
#  </div>
#  </div>
#  </div>,
#  <div class="mobile-menu-icon js-toggle-mobile-menu">
#  <div class="box">
#  <div class="inner"></div>
#  </div>
#  </div>,
#  <div class="box">
#  <div class="inner"></div>
#  </div>,
#  <div class="inner"></div>,
#  <div class="side-icons">
#  <span class="search-toggle js-toggle-search-bar">
#  <img alt="Pesquisa" class="search" height="32" src="/wp-content/themes/pingodoce/library/images/v2/icon-search.svg" width="32"/>
#  <img alt="Pesquisa" class="close" height="32" src="/wp-content/themes/pingodoce/library/images/v2/icon-close.svg" width="32"/>
#  </span>
#  <a href="/login/">
#  <img alt="Área de Utilizador" class="user-icon js-user-icon" height="32" src="/wp-content/themes/pingodoce/library/images/v2/icon-user.svg" width="32"/>
#  <img alt="Área de Utilizador" class="user-icon hidden js-user-icon-logged-in" height="32" src="/wp-content/themes/pingodoce/library/images/v2/icon-user-active.svg" width="32"/>
#  </a>
#  </div>,
#  <div class="mobile-menu js-mobile-menu">
#  <div>
#  <ul class="mobile-menu-entries">
#  <li class="menu-item menu-item-type-custom menu-item-object-custom menu-item-236493" id="menu-item-236493"><a href="/produtos/">Produtos</a></li>
#  <li class="menu-item menu-item-type-custom menu-item-object-custom menu-item-236491" id="menu-item-236491"><a href="/receitas/">Receitas</a></li>
#  <li class="menu-item menu-item-type-custom menu-item-object-custom menu-item-236499" id="menu-item-236499"><a href="/folhetos/">Folhetos</a></li>
#  <li class="menu-item menu-item-type-custom menu-item-object-custom menu-item-236498" id="menu-item-236498"><a href="/lojas/">Lojas</a></li>
#  <li class="menu-item menu-item-type-custom menu-item-object-custom menu-item-444552" id="menu-item-444552"><a href="/apoio-ao-cliente/">Apoio ao Cliente</a></li>
#  </ul>
#  <a class="pm" href="/pingodoce-institucional/cartao-poupa-mais/"><img alt="Poupa Mais" height="18" src="/wp-content/themes/pingodoce/library/images/v2/header-poupamais.png" width="28"/>Poupa Mais</a>
#  </div>
#  <div class="bottom-links-menu">
#  <ul class="expandable-items js-expandable-mobile-menu-items">
#  <li>
#  <a href="/sobre-nos/">Sobre nós</a> <span class="arrow"></span>
#  <ul class="subitems">
#  <li><a class="main-links" href="/junte-se-a-nos/">Junte-se a nós</a></li>
#  <li><a class="main-links" href="/pingodoce-institucional/revista-sabe-bem/">Revista Sabe Bem</a>
#  </li>
#  <li><a class="main-links" href="/sobre-nos/cartao-poupa-mais/">Cartão Poupa
#  							Mais</a></li>
#  <li><a class="main-links" href="/sobre-nos/cartao-presente-pingo-doce/">Cartão
#  							Presente</a></li>
#  <li><a class="main-links" href="/sobre-nos/cartao-bom-pingo-doce/">Cartão
#  							Bom</a></li>
#  <li><a class="main-links" href="/sobre-nos/noticias/">Notícias</a></li>
#  <li><a class="main-links" href="https://www.jeronimomartins.com" target="_blank">O grupo Jerónimo
#  							Martins</a></li>
#  <li><a class="main-links" href="/responsabilidade/premio-literatura-infantil/">Prémio Literatura Infantil</a></li>
#  </ul>
#  </li>
#  <li><a href="#">Responsabilidade</a> <span class="arrow"></span>
#  <ul class="subitems">
#  <li><a class="main-links" href="/responsabilidade/pedido-apoio">Pedido de Apoio</a></li>
#  <li><a class="main-links" href="/responsabilidade/#pilares-1">Promover a saúde pela alimentação</a><span class="arrow"></span>
#  <ul class="subitems">
#  <li><a class="main-links" href="https://menossalportugal.pt/" target="_blank">Menos Sal Portugal</a></li>
#  <li><a class="main-links" href="/responsabilidade/dieta-mediterranica/">Dieta Mediterrânica</a></li>
#  </ul>
#  </li>
#  <li><a class="main-links" href="/responsabilidade/#pilares-2">Preservar a Biodiversidade</a><span class="arrow"></span>
#  <ul class="subitems">
#  <li><a class="main-links" href="/responsabilidade/amar-o-mar/" target="_blank">Amar o Mar</a></li>
#  <li><a class="main-links" href="/responsabilidade/ecodesign-embalagens/">Ecodesign de Embalagens</a></li>
#  </ul>
#  </li>
#  <li><a class="main-links" href="/responsabilidade/#pilares-3">Compromisso com as pessoas</a><span class="arrow"></span>
#  <ul class="subitems">
#  <li><a class="main-links" href="/responsabilidade/bairro-feliz/" target="_blank">Bairro Feliz</a></li>
#  </ul>
#  </li>
#  <li><a class="main-links" href="/responsabilidade/#pilares-4">Promover a literacia infanto-juvenil</a><span class="arrow"></span>
#  <ul class="subitems">
#  <li><a class="main-links" href="/premio-literatura-infantil/" target="_blank">Prémio de Literatura Infantil</a></li>
#  </ul>
#  </li>
#  <li><a class="main-links" href="/responsabilidade/#pilares-5">Ser solidário</a></li>
#  </ul>
#  </li>
#  <li><a href="/junte-se-a-nos/">Junte-se a nós</a> <span class="arrow"></span>
#  <ul class="subitems">
#  <li><a class="main-links" href="/junte-se-a-nos/oportunidades/">Oportunidades</a></li>
#  <li><a class="main-links" href="/junte-se-a-nos/perguntas-respostas/">Perguntas e respostas</a></li>
#  </ul>
#  </li>
#  </ul>
#  <div class="side-by-side">
#  <a class="food" href="/produtos/take-away/encomendas/"><img alt="Comprar online" class="js-lazy-load" data-src="/wp-content/themes/pingodoce/library/images/v2/header-food.svg" height="24" src="..." width="24"/>Encomendar comida</a>
#  <a class="cart" href="https://mercadao.pt/store/pingo-doce?utm_source=pingo-doce&amp;utm_medium=botao-comprar-online&amp;utm_campaign=referencia-pingo-doce" rel="noopener" target="_blank"><img alt="Comprar online" class="js-lazy-load" data-src="/wp-content/themes/pingodoce/library/images/v2/header-cart.svg" height="24" src="..." width="24"/>Comprar online</a>
#  </div> </div>
#  </div>,
#  <div>
#  <ul class="mobile-menu-entries">
#  <li class="menu-item menu-item-type-custom menu-item-object-custom menu-item-236493" id="menu-item-236493"><a href="/produtos/">Produtos</a></li>
#  <li class="menu-item menu-item-type-custom menu-item-object-custom menu-item-236491" id="menu-item-236491"><a href="/receitas/">Receitas</a></li>
#  <li class="menu-item menu-item-type-custom menu-item-object-custom menu-item-236499" id="menu-item-236499"><a href="/folhetos/">Folhetos</a></li>
#  <li class="menu-item menu-item-type-custom menu-item-object-custom menu-item-236498" id="menu-item-236498"><a href="/lojas/">Lojas</a></li>
#  <li class="menu-item menu-item-type-custom menu-item-object-custom menu-item-444552" id="menu-item-444552"><a href="/apoio-ao-cliente/">Apoio ao Cliente</a></li>
#  </ul>
#  <a class="pm" href="/pingodoce-institucional/cartao-poupa-mais/"><img alt="Poupa Mais" height="18" src="/wp-content/themes/pingodoce/library/images/v2/header-poupamais.png" width="28"/>Poupa Mais</a>
#  </div>,
#  <div class="bottom-links-menu">
#  <ul class="expandable-items js-expandable-mobile-menu-items">
#  <li>
#  <a href="/sobre-nos/">Sobre nós</a> <span class="arrow"></span>
#  <ul class="subitems">
#  <li><a class="main-links" href="/junte-se-a-nos/">Junte-se a nós</a></li>
#  <li><a class="main-links" href="/pingodoce-institucional/revista-sabe-bem/">Revista Sabe Bem</a>
#  </li>
#  <li><a class="main-links" href="/sobre-nos/cartao-poupa-mais/">Cartão Poupa
#  							Mais</a></li>
#  <li><a class="main-links" href="/sobre-nos/cartao-presente-pingo-doce/">Cartão
#  							Presente</a></li>
#  <li><a class="main-links" href="/sobre-nos/cartao-bom-pingo-doce/">Cartão
#  							Bom</a></li>
#  <li><a class="main-links" href="/sobre-nos/noticias/">Notícias</a></li>
#  <li><a class="main-links" href="https://www.jeronimomartins.com" target="_blank">O grupo Jerónimo
#  							Martins</a></li>
#  <li><a class="main-links" href="/responsabilidade/premio-literatura-infantil/">Prémio Literatura Infantil</a></li>
#  </ul>
#  </li>
#  <li><a href="#">Responsabilidade</a> <span class="arrow"></span>
#  <ul class="subitems">
#  <li><a class="main-links" href="/responsabilidade/pedido-apoio">Pedido de Apoio</a></li>
#  <li><a class="main-links" href="/responsabilidade/#pilares-1">Promover a saúde pela alimentação</a><span class="arrow"></span>
#  <ul class="subitems">
#  <li><a class="main-links" href="https://menossalportugal.pt/" target="_blank">Menos Sal Portugal</a></li>
#  <li><a class="main-links" href="/responsabilidade/dieta-mediterranica/">Dieta Mediterrânica</a></li>
#  </ul>
#  </li>
#  <li><a class="main-links" href="/responsabilidade/#pilares-2">Preservar a Biodiversidade</a><span class="arrow"></span>
#  <ul class="subitems">
#  <li><a class="main-links" href="/responsabilidade/amar-o-mar/" target="_blank">Amar o Mar</a></li>
#  <li><a class="main-links" href="/responsabilidade/ecodesign-embalagens/">Ecodesign de Embalagens</a></li>
#  </ul>
#  </li>
#  <li><a class="main-links" href="/responsabilidade/#pilares-3">Compromisso com as pessoas</a><span class="arrow"></span>
#  <ul class="subitems">
#  <li><a class="main-links" href="/responsabilidade/bairro-feliz/" target="_blank">Bairro Feliz</a></li>
#  </ul>
#  </li>
#  <li><a class="main-links" href="/responsabilidade/#pilares-4">Promover a literacia infanto-juvenil</a><span class="arrow"></span>
#  <ul class="subitems">
#  <li><a class="main-links" href="/premio-literatura-infantil/" target="_blank">Prémio de Literatura Infantil</a></li>
#  </ul>
#  </li>
#  <li><a class="main-links" href="/responsabilidade/#pilares-5">Ser solidário</a></li>
#  </ul>
#  </li>
#  <li><a href="/junte-se-a-nos/">Junte-se a nós</a> <span class="arrow"></span>
#  <ul class="subitems">
#  <li><a class="main-links" href="/junte-se-a-nos/oportunidades/">Oportunidades</a></li>
#  <li><a class="main-links" href="/junte-se-a-nos/perguntas-respostas/">Perguntas e respostas</a></li>
#  </ul>
#  </li>
#  </ul>
#  <div class="side-by-side">
#  <a class="food" href="/produtos/take-away/encomendas/"><img alt="Comprar online" class="js-lazy-load" data-src="/wp-content/themes/pingodoce/library/images/v2/header-food.svg" height="24" src="..." width="24"/>Encomendar comida</a>
#  <a class="cart" href="https://mercadao.pt/store/pingo-doce?utm_source=pingo-doce&amp;utm_medium=botao-comprar-online&amp;utm_campaign=referencia-pingo-doce" rel="noopener" target="_blank"><img alt="Comprar online" class="js-lazy-load" data-src="/wp-content/themes/pingodoce/library/images/v2/header-cart.svg" height="24" src="..." width="24"/>Comprar online</a>
#  </div> </div>,
#  <div class="side-by-side">
#  <a class="food" href="/produtos/take-away/encomendas/"><img alt="Comprar online" class="js-lazy-load" data-src="/wp-content/themes/pingodoce/library/images/v2/header-food.svg" height="24" src="..." width="24"/>Encomendar comida</a>
#  <a class="cart" href="https://mercadao.pt/store/pingo-doce?utm_source=pingo-doce&amp;utm_medium=botao-comprar-online&amp;utm_campaign=referencia-pingo-doce" rel="noopener" target="_blank"><img alt="Comprar online" class="js-lazy-load" data-src="/wp-content/themes/pingodoce/library/images/v2/header-cart.svg" height="24" src="..." width="24"/>Comprar online</a>
#  </div>,
#  <div class="search-bar js-search-bar">
#  <form action="/" class="container" method="get">
#  <input aria-label="Pesquise no site Pingo Doce" class="search-input" name="s" placeholder="Pesquise no site Pingo Doce" type="search"/>
#  <span class="reset-text js-reset-global-search-input"></span>
#  <button aria-label="Pesquisar" class="button-search" type="submit"></button>
#  </form>
#  </div>,
#  <div class="breadcrumbs-v2__wrapper" style="">
#  <div class="container breadcrumbs-v2 js-breadcrumbs">
#  <ul class="breadcrumbs-v2-area">
#  <li class="">
#  <a href="/">
#
#                          Home
#                                              </a>
#  </li>
#  <li class="">
#  <a href="https://www.pingodoce.pt/produtos/">
#
#                          Produtos
#                                              </a>
#  </li>
#  <li class="">
#  <a href="https://www.pingodoce.pt/produtos/marca-propria-pingo-doce/">
#
#                          As Nossas Marcas
#                                              </a>
#  </li>
#  <li class="active">
#
#                          Cuida Bebé
#                                          </li>
#  </ul>
#  </div>
#  <div class="container breadcrumbs-v2 mobile--only js-breadcrumbs">
#  <ul class="breadcrumbs-v2-area">
#  <li>
#  <a href="https://www.pingodoce.pt/produtos/marca-propria-pingo-doce/">
#  <img class="js-lazy-load" data-src="https://www.pingodoce.pt/wp-content/themes/pingodoce/library/images/arrow-right-black.png" src="..."/>
#                          As Nossas Marcas                    </a>
#  </li>
#  </ul>
#  </div>
#  </div>,
#  <div class="container breadcrumbs-v2 js-breadcrumbs">
#  <ul class="breadcrumbs-v2-area">
#  <li class="">
#  <a href="/">
#
#                          Home
#                                              </a>
#  </li>
#  <li class="">
#  <a href="https://www.pingodoce.pt/produtos/">
#
#                          Produtos
#                                              </a>
#  </li>
#  <li class="">
#  <a href="https://www.pingodoce.pt/produtos/marca-propria-pingo-doce/">
#
#                          As Nossas Marcas
#                                              </a>
#  </li>
#  <li class="active">
#
#                          Cuida Bebé
#                                          </li>
#  </ul>
#  </div>,
#  <div class="container breadcrumbs-v2 mobile--only js-breadcrumbs">
#  <ul class="breadcrumbs-v2-area">
#  <li>
#  <a href="https://www.pingodoce.pt/produtos/marca-propria-pingo-doce/">
#  <img class="js-lazy-load" data-src="https://www.pingodoce.pt/wp-content/themes/pingodoce/library/images/arrow-right-black.png" src="..."/>
#                          As Nossas Marcas                    </a>
#  </li>
#  </ul>
#  </div>,
#  <div class="header-product-brand-pd">
#  <div class="container">
#  <div class="header-product-brand-pd__image-container">
#  <img alt="Cuida Bebé" class="js-lazy-load header-product-brand-pd__image" data-src="https://www.pingodoce.pt/wp-content/uploads/2019/05/cuidabebe.png" src="..." width="480"/>
#  </div>
#  <div class="header-product-brand-pd__content">
#  <img alt="Cuida Bebé" class="js-lazy-load header-product-brand-pd__logo" data-src="https://www.pingodoce.pt/wp-content/uploads/2019/05/cuidabebe-lg.png" src="..." width="134"/>
#  <div class="content">
#  <h1 class="brand-name">Cuida Bebé</h1>
#  <p>
#  <!--(figmeta)eyJmaWxlS2V5IjoiNG1WYnpPeTAyeWNyVU14NDNRTjNxeiIsInBhc3RlSUQiOi0xLCJkYXRhVHlwZSI6InNjZW5lIn0K(/figmeta)--><!--(figma)...(/figma)-->A marca <strong>Pingo Doce Cuida Bebé</strong> tem produtos alimentares e não alimentares desenvolvidos a pensar no conforto, segurança e crescimento do seu bebé. Todos os produtos foram submetidos a testes rigorosos para garantir que o seu bebé tem sempre o melhor.					</p>
#  </div>
#  </div>
#  </div>
#  </div>,
#  <div class="container">
#  <div class="header-product-brand-pd__image-container">
#  <img alt="Cuida Bebé" class="js-lazy-load header-product-brand-pd__image" data-src="https://www.pingodoce.pt/wp-content/uploads/2019/05/cuidabebe.png" src="..." width="480"/>
#  </div>
#  <div class="header-product-brand-pd__content">
#  <img alt="Cuida Bebé" class="js-lazy-load header-product-brand-pd__logo" data-src="https://www.pingodoce.pt/wp-content/uploads/2019/05/cuidabebe-lg.png" src="..." width="134"/>
#  <div class="content">
#  <h1 class="brand-name">Cuida Bebé</h1>
#  <p>
#  <!--(figmeta)eyJmaWxlS2V5IjoiNG1WYnpPeTAyeWNyVU14NDNRTjNxeiIsInBhc3RlSUQiOi0xLCJkYXRhVHlwZSI6InNjZW5lIn0K(/figmeta)--><!--(figma)...(/figma)-->A marca <strong>Pingo Doce Cuida Bebé</strong> tem produtos alimentares e não alimentares desenvolvidos a pensar no conforto, segurança e crescimento do seu bebé. Todos os produtos foram submetidos a testes rigorosos para garantir que o seu bebé tem sempre o melhor.					</p>
#  </div>
#  </div>
#  </div>,
#  <div class="header-product-brand-pd__image-container">
#  <img alt="Cuida Bebé" class="js-lazy-load header-product-brand-pd__image" data-src="https://www.pingodoce.pt/wp-content/uploads/2019/05/cuidabebe.png" src="..." width="480"/>
#  </div>,
#  <div class="header-product-brand-pd__content">
#  <img alt="Cuida Bebé" class="js-lazy-load header-product-brand-pd__logo" data-src="https://www.pingodoce.pt/wp-content/uploads/2019/05/cuidabebe-lg.png" src="..." width="134"/>
#  <div class="content">
#  <h1 class="brand-name">Cuida Bebé</h1>
#  <p>
#  <!--(figmeta)eyJmaWxlS2V5IjoiNG1WYnpPeTAyeWNyVU14NDNRTjNxeiIsInBhc3RlSUQiOi0xLCJkYXRhVHlwZSI6InNjZW5lIn0K(/figmeta)--><!--(figma)...(/figma)-->A marca <strong>Pingo Doce Cuida Bebé</strong> tem produtos alimentares e não alimentares desenvolvidos a pensar no conforto, segurança e crescimento do seu bebé. Todos os produtos foram submetidos a testes rigorosos para garantir que o seu bebé tem sempre o melhor.					</p>
#  </div>
#  </div>,
#  <div class="content">
#  <h1 class="brand-name">Cuida Bebé</h1>
#  <p>
#  <!--(figmeta)eyJmaWxlS2V5IjoiNG1WYnpPeTAyeWNyVU14NDNRTjNxeiIsInBhc3RlSUQiOi0xLCJkYXRhVHlwZSI6InNjZW5lIn0K(/figmeta)--><!--(figma)...(/figma)-->A marca <strong>Pingo Doce Cuida Bebé</strong> tem produtos alimentares e não alimentares desenvolvidos a pensar no conforto, segurança e crescimento do seu bebé. Todos os produtos foram submetidos a testes rigorosos para garantir que o seu bebé tem sempre o melhor.					</p>
#  </div>,
#  <div class="search-product__wrapper">
#  <div class="container container-header">
#  <div class="row">
#  <div class="col-xs-12 pesquisa-title">
#  <h2>
#                      Encontre os produtos desta marca                </h2>
#  </div>
#  <div class="col-xs-12 pesquisa">
#  <div class="search-input-component">
#  <form action="" autocomplete="off" class="form js-search-form" data-auto-complete=".js-auto-complete-60c9bf50c4657" data-auto-complete-input="#input-60c9bf50c4657" data-auto-complete-params="action=custom-search-autocomplete&amp;type=product&amp;brand=12961&amp;query=" data-endpoint="/wp-content/themes/pingodoce/ajax/pd-ajax.php?action=custom-search&amp;context=&amp;type=product&amp;page=1&amp;category=&amp;brand=12961&amp;query=" data-ga-pageview="/produtos/marca-propria-pingo-doce/cuida-bebe/?brand=12961query=" data-paginator=".js-product-brand-paginator" method="get">
#  <input aria-label="Pesquisa" class="text--input js-v2-focus-input" id="input-60c9bf50c4657" name="" placeholder="Pesquisar produtos" type="search" value=""/>
#  <input aria-label="Pesquisar" class="button-search input60c9bf50c4657" type="submit" value=""/>
#  <span class="reset--text--input js-reset-search-input"></span>
#  <ul class="auto-complete-wrapper js-auto-complete-60c9bf50c4657"></ul>
#  </form>
#  </div>
#  </div>
#  </div>
#  </div>
#  <div class="container js-product-brand-paginator results-paginator" data-address-params="?query={{query}}&amp;brand={{brand}}&amp;category={{category}}&amp;page={{page}}" data-results-paginator="/wp-content/themes/pingodoce/ajax/pd-ajax.php?action=custom-search&amp;context=&amp;type=product&amp;page=1&amp;category=&amp;brand=12961&amp;query=">
#  <!--pagination-->
#  <div class="row">
#  <div class="col-xs-12 paginator-top-list">
#  <div class="pagination product-brand-page-pagination js-pagination">
#  <div class="pagination-left product-brand-page-pagination-left">
#  <p>
#  <span class="total_results"></span> Resultados
#          </p>
#  </div>
#  <div class="pagination-right product-brand-page-pagination-right">
#  <!-- PREVIOUS BUTTON-->
#  <button class="page-nav previous-page js-page-nav">
#  <img alt="Página anterior" class="js-lazy-load" data-src="/wp-content/themes/pingodoce/library/images/v2/icon-arrow-previous-pag.svg" height="14" src="..." width="8"/>
#  </button>
#  <!-- PAGINATION CONTENT-->
#  <p class="range-pages">
#  <span class="current_page"></span>
#              de <span class="total_pages"></span>
#  </p>
#  <!-- NEXT BUTTON-->
#  <button class="page-nav next-page js-page-nav">
#  <img alt="Página seguinte" class="js-lazy-load" data-src="/wp-content/themes/pingodoce/library/images/v2/icon-arrow-next-pag.svg" height="14" src="..." width="8"/>
#  </button>
#  </div>
#  </div></div>
#  </div>
#  <div class="results-paginator__list-wrapper">
#  <span class="js-no-results results-paginator__no-results">Não foram encontrados resultados</span>
#  <span class="js-loading loader loader-spinner"> </span>
#  <div class="results-paginator__list" data-results-container=""></div>
#  </div>
#  <!--pagination-->
#  <div class="row">
#  <div class="col-xs-12 paginator-bottom-list">
#  <div class="pagination product-brand-page-pagination js-pagination">
#  <div class="pagination-left product-brand-page-pagination-left">
#  <p>
#  <span class="total_results"></span> Resultados
#          </p>
#  </div>
#  <div class="pagination-right product-brand-page-pagination-right">
#  <!-- PREVIOUS BUTTON-->
#  <button class="page-nav previous-page js-page-nav">
#  <img alt="Página anterior" class="js-lazy-load" data-src="/wp-content/themes/pingodoce/library/images/v2/icon-arrow-previous-pag.svg" height="14" src="..." width="8"/>
#  </button>
#  <!-- PAGINATION CONTENT-->
#  <p class="range-pages">
#  <span class="current_page"></span>
#              de <span class="total_pages"></span>
#  </p>
#  <!-- NEXT BUTTON-->
#  <button class="page-nav next-page js-page-nav">
#  <img alt="Página seguinte" class="js-lazy-load" data-src="/wp-content/themes/pingodoce/library/images/v2/icon-arrow-next-pag.svg" height="14" src="..." width="8"/>
#  </button>
#  </div>
#  </div></div>
#  </div>
#  </div>
#  </div>,
#  <div class="container container-header">
#  <div class="row">
#  <div class="col-xs-12 pesquisa-title">
#  <h2>
#                      Encontre os produtos desta marca                </h2>
#  </div>
#  <div class="col-xs-12 pesquisa">
#  <div class="search-input-component">
#  <form action="" autocomplete="off" class="form js-search-form" data-auto-complete=".js-auto-complete-60c9bf50c4657" data-auto-complete-input="#input-60c9bf50c4657" data-auto-complete-params="action=custom-search-autocomplete&amp;type=product&amp;brand=12961&amp;query=" data-endpoint="/wp-content/themes/pingodoce/ajax/pd-ajax.php?action=custom-search&amp;context=&amp;type=product&amp;page=1&amp;category=&amp;brand=12961&amp;query=" data-ga-pageview="/produtos/marca-propria-pingo-doce/cuida-bebe/?brand=12961query=" data-paginator=".js-product-brand-paginator" method="get">
#  <input aria-label="Pesquisa" class="text--input js-v2-focus-input" id="input-60c9bf50c4657" name="" placeholder="Pesquisar produtos" type="search" value=""/>
#  <input aria-label="Pesquisar" class="button-search input60c9bf50c4657" type="submit" value=""/>
#  <span class="reset--text--input js-reset-search-input"></span>
#  <ul class="auto-complete-wrapper js-auto-complete-60c9bf50c4657"></ul>
#  </form>
#  </div>
#  </div>
#  </div>
#  </div>,
#  <div class="row">
#  <div class="col-xs-12 pesquisa-title">
#  <h2>
#                      Encontre os produtos desta marca                </h2>
#  </div>
#  <div class="col-xs-12 pesquisa">
#  <div class="search-input-component">
#  <form action="" autocomplete="off" class="form js-search-form" data-auto-complete=".js-auto-complete-60c9bf50c4657" data-auto-complete-input="#input-60c9bf50c4657" data-auto-complete-params="action=custom-search-autocomplete&amp;type=product&amp;brand=12961&amp;query=" data-endpoint="/wp-content/themes/pingodoce/ajax/pd-ajax.php?action=custom-search&amp;context=&amp;type=product&amp;page=1&amp;category=&amp;brand=12961&amp;query=" data-ga-pageview="/produtos/marca-propria-pingo-doce/cuida-bebe/?brand=12961query=" data-paginator=".js-product-brand-paginator" method="get">
#  <input aria-label="Pesquisa" class="text--input js-v2-focus-input" id="input-60c9bf50c4657" name="" placeholder="Pesquisar produtos" type="search" value=""/>
#  <input aria-label="Pesquisar" class="button-search input60c9bf50c4657" type="submit" value=""/>
#  <span class="reset--text--input js-reset-search-input"></span>
#  <ul class="auto-complete-wrapper js-auto-complete-60c9bf50c4657"></ul>
#  </form>
#  </div>
#  </div>
#  </div>,
#  <div class="col-xs-12 pesquisa-title">
#  <h2>
#                      Encontre os produtos desta marca                </h2>
#  </div>,
#  <div class="col-xs-12 pesquisa">
#  <div class="search-input-component">
#  <form action="" autocomplete="off" class="form js-search-form" data-auto-complete=".js-auto-complete-60c9bf50c4657" data-auto-complete-input="#input-60c9bf50c4657" data-auto-complete-params="action=custom-search-autocomplete&amp;type=product&amp;brand=12961&amp;query=" data-endpoint="/wp-content/themes/pingodoce/ajax/pd-ajax.php?action=custom-search&amp;context=&amp;type=product&amp;page=1&amp;category=&amp;brand=12961&amp;query=" data-ga-pageview="/produtos/marca-propria-pingo-doce/cuida-bebe/?brand=12961query=" data-paginator=".js-product-brand-paginator" method="get">
#  <input aria-label="Pesquisa" class="text--input js-v2-focus-input" id="input-60c9bf50c4657" name="" placeholder="Pesquisar produtos" type="search" value=""/>
#  <input aria-label="Pesquisar" class="button-search input60c9bf50c4657" type="submit" value=""/>
#  <span class="reset--text--input js-reset-search-input"></span>
#  <ul class="auto-complete-wrapper js-auto-complete-60c9bf50c4657"></ul>
#  </form>
#  </div>
#  </div>,
#  <div class="search-input-component">
#  <form action="" autocomplete="off" class="form js-search-form" data-auto-complete=".js-auto-complete-60c9bf50c4657" data-auto-complete-input="#input-60c9bf50c4657" data-auto-complete-params="action=custom-search-autocomplete&amp;type=product&amp;brand=12961&amp;query=" data-endpoint="/wp-content/themes/pingodoce/ajax/pd-ajax.php?action=custom-search&amp;context=&amp;type=product&amp;page=1&amp;category=&amp;brand=12961&amp;query=" data-ga-pageview="/produtos/marca-propria-pingo-doce/cuida-bebe/?brand=12961query=" data-paginator=".js-product-brand-paginator" method="get">
#  <input aria-label="Pesquisa" class="text--input js-v2-focus-input" id="input-60c9bf50c4657" name="" placeholder="Pesquisar produtos" type="search" value=""/>
#  <input aria-label="Pesquisar" class="button-search input60c9bf50c4657" type="submit" value=""/>
#  <span class="reset--text--input js-reset-search-input"></span>
#  <ul class="auto-complete-wrapper js-auto-complete-60c9bf50c4657"></ul>
#  </form>
#  </div>,
#  <div class="container js-product-brand-paginator results-paginator" data-address-params="?query={{query}}&amp;brand={{brand}}&amp;category={{category}}&amp;page={{page}}" data-results-paginator="/wp-content/themes/pingodoce/ajax/pd-ajax.php?action=custom-search&amp;context=&amp;type=product&amp;page=1&amp;category=&amp;brand=12961&amp;query=">
#  <!--pagination-->
#  <div class="row">
#  <div class="col-xs-12 paginator-top-list">
#  <div class="pagination product-brand-page-pagination js-pagination">
#  <div class="pagination-left product-brand-page-pagination-left">
#  <p>
#  <span class="total_results"></span> Resultados
#          </p>
#  </div>
#  <div class="pagination-right product-brand-page-pagination-right">
#  <!-- PREVIOUS BUTTON-->
#  <button class="page-nav previous-page js-page-nav">
#  <img alt="Página anterior" class="js-lazy-load" data-src="/wp-content/themes/pingodoce/library/images/v2/icon-arrow-previous-pag.svg" height="14" src="..." width="8"/>
#  </button>
#  <!-- PAGINATION CONTENT-->
#  <p class="range-pages">
#  <span class="current_page"></span>
#              de <span class="total_pages"></span>
#  </p>
#  <!-- NEXT BUTTON-->
#  <button class="page-nav next-page js-page-nav">
#  <img alt="Página seguinte" class="js-lazy-load" data-src="/wp-content/themes/pingodoce/library/images/v2/icon-arrow-next-pag.svg" height="14" src="..." width="8"/>
#  </button>
#  </div>
#  </div></div>
#  </div>
#  <div class="results-paginator__list-wrapper">
#  <span class="js-no-results results-paginator__no-results">Não foram encontrados resultados</span>
#  <span class="js-loading loader loader-spinner"> </span>
#  <div class="results-paginator__list" data-results-container=""></div>
#  </div>
#  <!--pagination-->
#  <div class="row">
#  <div class="col-xs-12 paginator-bottom-list">
#  <div class="pagination product-brand-page-pagination js-pagination">
#  <div class="pagination-left product-brand-page-pagination-left">
#  <p>
#  <span class="total_results"></span> Resultados
#          </p>
#  </div>
#  <div class="pagination-right product-brand-page-pagination-right">
#  <!-- PREVIOUS BUTTON-->
#  <button class="page-nav previous-page js-page-nav">
#  <img alt="Página anterior" class="js-lazy-load" data-src="/wp-content/themes/pingodoce/library/images/v2/icon-arrow-previous-pag.svg" height="14" src="..." width="8"/>
#  </button>
#  <!-- PAGINATION CONTENT-->
#  <p class="range-pages">
#  <span class="current_page"></span>
#              de <span class="total_pages"></span>
#  </p>
#  <!-- NEXT BUTTON-->
#  <button class="page-nav next-page js-page-nav">
#  <img alt="Página seguinte" class="js-lazy-load" data-src="/wp-content/themes/pingodoce/library/images/v2/icon-arrow-next-pag.svg" height="14" src="..." width="8"/>
#  </button>
#  </div>
#  </div></div>
#  </div>
#  </div>,
#  <div class="row">
#  <div class="col-xs-12 paginator-top-list">
#  <div class="pagination product-brand-page-pagination js-pagination">
#  <div class="pagination-left product-brand-page-pagination-left">
#  <p>
#  <span class="total_results"></span> Resultados
#          </p>
#  </div>
#  <div class="pagination-right product-brand-page-pagination-right">
#  <!-- PREVIOUS BUTTON-->
#  <button class="page-nav previous-page js-page-nav">
#  <img alt="Página anterior" class="js-lazy-load" data-src="/wp-content/themes/pingodoce/library/images/v2/icon-arrow-previous-pag.svg" height="14" src="..." width="8"/>
#  </button>
#  <!-- PAGINATION CONTENT-->
#  <p class="range-pages">
#  <span class="current_page"></span>
#              de <span class="total_pages"></span>
#  </p>
#  <!-- NEXT BUTTON-->
#  <button class="page-nav next-page js-page-nav">
#  <img alt="Página seguinte" class="js-lazy-load" data-src="/wp-content/themes/pingodoce/library/images/v2/icon-arrow-next-pag.svg" height="14" src="..." width="8"/>
#  </button>
#  </div>
#  </div></div>
#  </div>,
#  <div class="col-xs-12 paginator-top-list">
#  <div class="pagination product-brand-page-pagination js-pagination">
#  <div class="pagination-left product-brand-page-pagination-left">
#  <p>
#  <span class="total_results"></span> Resultados
#          </p>
#  </div>
#  <div class="pagination-right product-brand-page-pagination-right">
#  <!-- PREVIOUS BUTTON-->
#  <button class="page-nav previous-page js-page-nav">
#  <img alt="Página anterior" class="js-lazy-load" data-src="/wp-content/themes/pingodoce/library/images/v2/icon-arrow-previous-pag.svg" height="14" src="..." width="8"/>
#  </button>
#  <!-- PAGINATION CONTENT-->
#  <p class="range-pages">
#  <span class="current_page"></span>
#              de <span class="total_pages"></span>
#  </p>
#  <!-- NEXT BUTTON-->
#  <button class="page-nav next-page js-page-nav">
#  <img alt="Página seguinte" class="js-lazy-load" data-src="/wp-content/themes/pingodoce/library/images/v2/icon-arrow-next-pag.svg" height="14" src="..." width="8"/>
#  </button>
#  </div>
#  </div></div>,
#  <div class="pagination product-brand-page-pagination js-pagination">
#  <div class="pagination-left product-brand-page-pagination-left">
#  <p>
#  <span class="total_results"></span> Resultados
#          </p>
#  </div>
#  <div class="pagination-right product-brand-page-pagination-right">
#  <!-- PREVIOUS BUTTON-->
#  <button class="page-nav previous-page js-page-nav">
#  <img alt="Página anterior" class="js-lazy-load" data-src="/wp-content/themes/pingodoce/library/images/v2/icon-arrow-previous-pag.svg" height="14" src="..." width="8"/>
#  </button>
#  <!-- PAGINATION CONTENT-->
#  <p class="range-pages">
#  <span class="current_page"></span>
#              de <span class="total_pages"></span>
#  </p>
#  <!-- NEXT BUTTON-->
#  <button class="page-nav next-page js-page-nav">
#  <img alt="Página seguinte" class="js-lazy-load" data-src="/wp-content/themes/pingodoce/library/images/v2/icon-arrow-next-pag.svg" height="14" src="..." width="8"/>
#  </button>
#  </div>
#  </div>,
#  <div class="pagination-left product-brand-page-pagination-left">
#  <p>
#  <span class="total_results"></span> Resultados
#          </p>
#  </div>,
#  <div class="pagination-right product-brand-page-pagination-right">
#  <!-- PREVIOUS BUTTON-->
#  <button class="page-nav previous-page js-page-nav">
#  <img alt="Página anterior" class="js-lazy-load" data-src="/wp-content/themes/pingodoce/library/images/v2/icon-arrow-previous-pag.svg" height="14" src="..." width="8"/>
#  </button>
#  <!-- PAGINATION CONTENT-->
#  <p class="range-pages">
#  <span class="current_page"></span>
#              de <span class="total_pages"></span>
#  </p>
#  <!-- NEXT BUTTON-->
#  <button class="page-nav next-page js-page-nav">
#  <img alt="Página seguinte" class="js-lazy-load" data-src="/wp-content/themes/pingodoce/library/images/v2/icon-arrow-next-pag.svg" height="14" src="..." width="8"/>
#  </button>
#  </div>,
#  <div class="results-paginator__list-wrapper">
#  <span class="js-no-results results-paginator__no-results">Não foram encontrados resultados</span>
#  <span class="js-loading loader loader-spinner"> </span>
#  <div class="results-paginator__list" data-results-container=""></div>
#  </div>,
#  <div class="results-paginator__list" data-results-container=""></div>,
#  <div class="row">
#  <div class="col-xs-12 paginator-bottom-list">
#  <div class="pagination product-brand-page-pagination js-pagination">
#  <div class="pagination-left product-brand-page-pagination-left">
#  <p>
#  <span class="total_results"></span> Resultados
#          </p>
#  </div>
#  <div class="pagination-right product-brand-page-pagination-right">
#  <!-- PREVIOUS BUTTON-->
#  <button class="page-nav previous-page js-page-nav">
#  <img alt="Página anterior" class="js-lazy-load" data-src="/wp-content/themes/pingodoce/library/images/v2/icon-arrow-previous-pag.svg" height="14" src="..." width="8"/>
#  </button>
#  <!-- PAGINATION CONTENT-->
#  <p class="range-pages">
#  <span class="current_page"></span>
#              de <span class="total_pages"></span>
#  </p>
#  <!-- NEXT BUTTON-->
#  <button class="page-nav next-page js-page-nav">
#  <img alt="Página seguinte" class="js-lazy-load" data-src="/wp-content/themes/pingodoce/library/images/v2/icon-arrow-next-pag.svg" height="14" src="..." width="8"/>
#  </button>
#  </div>
#  </div></div>
#  </div>,
#  <div class="col-xs-12 paginator-bottom-list">
#  <div class="pagination product-brand-page-pagination js-pagination">
#  <div class="pagination-left product-brand-page-pagination-left">
#  <p>
#  <span class="total_results"></span> Resultados
#          </p>
#  </div>
#  <div class="pagination-right product-brand-page-pagination-right">
#  <!-- PREVIOUS BUTTON-->
#  <button class="page-nav previous-page js-page-nav">
#  <img alt="Página anterior" class="js-lazy-load" data-src="/wp-content/themes/pingodoce/library/images/v2/icon-arrow-previous-pag.svg" height="14" src="..." width="8"/>
#  </button>
#  <!-- PAGINATION CONTENT-->
#  <p class="range-pages">
#  <span class="current_page"></span>
#              de <span class="total_pages"></span>
#  </p>
#  <!-- NEXT BUTTON-->
#  <button class="page-nav next-page js-page-nav">
#  <img alt="Página seguinte" class="js-lazy-load" data-src="/wp-content/themes/pingodoce/library/images/v2/icon-arrow-next-pag.svg" height="14" src="..." width="8"/>
#  </button>
#  </div>
#  </div></div>,
#  <div class="pagination product-brand-page-pagination js-pagination">
#  <div class="pagination-left product-brand-page-pagination-left">
#  <p>
#  <span class="total_results"></span> Resultados
#          </p>
#  </div>
#  <div class="pagination-right product-brand-page-pagination-right">
#  <!-- PREVIOUS BUTTON-->
#  <button class="page-nav previous-page js-page-nav">
#  <img alt="Página anterior" class="js-lazy-load" data-src="/wp-content/themes/pingodoce/library/images/v2/icon-arrow-previous-pag.svg" height="14" src="..." width="8"/>
#  </button>
#  <!-- PAGINATION CONTENT-->
#  <p class="range-pages">
#  <span class="current_page"></span>
#              de <span class="total_pages"></span>
#  </p>
#  <!-- NEXT BUTTON-->
#  <button class="page-nav next-page js-page-nav">
#  <img alt="Página seguinte" class="js-lazy-load" data-src="/wp-content/themes/pingodoce/library/images/v2/icon-arrow-next-pag.svg" height="14" src="..." width="8"/>
#  </button>
#  </div>
#  </div>,
#  <div class="pagination-left product-brand-page-pagination-left">
#  <p>
#  <span class="total_results"></span> Resultados
#          </p>
#  </div>,
#  <div class="pagination-right product-brand-page-pagination-right">
#  <!-- PREVIOUS BUTTON-->
#  <button class="page-nav previous-page js-page-nav">
#  <img alt="Página anterior" class="js-lazy-load" data-src="/wp-content/themes/pingodoce/library/images/v2/icon-arrow-previous-pag.svg" height="14" src="..." width="8"/>
#  </button>
#  <!-- PAGINATION CONTENT-->
#  <p class="range-pages">
# ...
#  <a class="hide-desktop sitemap-links" href="/produtos/marca-propria-pingo-doce/electric-co/">Electric Co</a>
#  </div>,
#  <div class="first-level hide-mobile">
#  <div class="second-level extra-paddingtop">
#  <a class="sitemap-links" href="/produtos/marca-propria-pingo-doce/ultra-pro/">Ultra</a>
#  <a class="sitemap-links" href="/produtos/marca-propria-pingo-doce/be-beauty/">Be Beauty</a>
#  <a class="sitemap-links" href="/produtos/marca-propria-pingo-doce/skino/">Skino</a>
#  <a class="sitemap-links" href="/produtos/marca-propria-pingo-doce/activpet/">ActivPet</a>
#  <a class="sitemap-links" href="/produtos/marca-propria-pingo-doce/electric-co/">Electric Co</a>
#  </div>
#  </div>,
#  <div class="second-level extra-paddingtop">
#  <a class="sitemap-links" href="/produtos/marca-propria-pingo-doce/ultra-pro/">Ultra</a>
#  <a class="sitemap-links" href="/produtos/marca-propria-pingo-doce/be-beauty/">Be Beauty</a>
#  <a class="sitemap-links" href="/produtos/marca-propria-pingo-doce/skino/">Skino</a>
#  <a class="sitemap-links" href="/produtos/marca-propria-pingo-doce/activpet/">ActivPet</a>
#  <a class="sitemap-links" href="/produtos/marca-propria-pingo-doce/electric-co/">Electric Co</a>
#  </div>,
#  <div class="level-group">
#  <div class="first-level">
#  <a class="title hidden-mobile" href="/lojas/">Lojas</a>
#  <span class="title hidden-desktop">Lojas</span>
#  <div class="second-level">
#  <a class="sitemap-links" href="/servicos-loja/restaurante/">Restaurante</a>
#  <a class="sitemap-links" href="/servicos-loja/cafe-e-bolos/">Café e Bolos</a>
#  <a class="sitemap-links" href="/servicos-loja/bemestar-saude-e-beleza/">Bem Estar</a>
#  <a class="sitemap-links" href="/servicos-loja/code-vestuario/">Code</a>
#  <a class="sitemap-links" href="/servicos-loja/postos-de-combustivel/">Postos de Combustível</a>
#  </div>
#  </div>
#  <div class="first-level">
#  <a class="title hidden-mobile" href="/lojas/">Serviços</a>
#  <span class="title hidden-desktop">Serviços</span>
#  <div class="second-level">
#  <a class="sitemap-links" href="/servicos-loja/entregas-ao-domicilio/">Entregas ao Domicílio</a>
#  <a class="sitemap-links" href="/produtos/take-away/encomendas/">Encomendas Take Away</a>
#  <a class="sitemap-links" href="/servicos-loja/agua-filtrada-eco/">Água Filtrada ECO</a>
#  <a class="sitemap-links" href="/lojas/?servicos=ecoponto-pilhas">Ecopontos</a>
#  </div>
#  </div>
#  <div class="first-level">
#  <a class="title hidden-mobile" href="/sobre-nos/">Sobre Nós</a>
#  <span class="title hidden-desktop">Sobre Nós</span>
#  <div class="second-level">
#  <a class="sitemap-links" href="/sobre-nos/noticias/">Notícias</a>
#  <a class="sitemap-links" href="/sobre-nos/cartao-poupa-mais/">Cartão Poupa Mais</a>
#  <a class="sitemap-links" href="/sobre-nos/cartao-presente-pingo-doce/">Cartão Presente</a>
#  <a class="sitemap-links" href="/sobre-nos/cartao-bom-pingo-doce/">Cartão Bom</a>
#  </div>
#  </div>
#  <div class="first-level">
#  <a class="title hidden-mobile" href="/responsabilidade/">Responsabilidade</a>
#  <span class="title hidden-desktop">Responsabilidade</span>
#  <div class="second-level">
#  <span class="info">Áreas Prioritárias</span>
#  <a class="sitemap-links" href="/responsabilidade/#pilares-1">Saúde pela alimentação</a>
#  <a class="sitemap-links" href="/responsabilidade/#pilares-2">Biodiversidade</a>
#  <a class="sitemap-links" href="/responsabilidade/#pilares-3">Pessoas</a>
#  <a class="sitemap-links" href="/responsabilidade/#pilares-4">Literacia infanto-juvenil</a>
#  <a class="sitemap-links" href="/responsabilidade/#pilares-5">Ser solidário</a>
#  <span class="info hidden-desktop">Iniciativas</span>
#  <a class="sitemap-links hide-desktop" href="/responsabilidade/premio-literatura-infantil/">Prémio de Literatura Infantil</a>
#  <a class="sitemap-links hide-desktop" href="/responsabilidade/bairro-feliz/">Bairro Feliz</a>
#  <a class="sitemap-links hide-desktop" href="/responsabilidade/dieta-mediterranica/">Dieta Mediterrânica</a>
#  <a class="sitemap-links hide-desktop" href="https://menossalportugal.pt/" target="_blank">Menos Sal Portugal</a>
#  <a class="sitemap-links hide-desktop" href="/responsabilidade/amar-o-mar/">Amar o Mar</a>
#  <a class="sitemap-links hide-desktop" href="/responsabilidade/ecodesign-embalagens/">Ecodesign</a>
#  </div>
#  </div>
#  <div class="first-level hide-mobile">
#  <div class="second-level extra-paddingtop">
#  <span class="info">Iniciativas</span>
#  <a class="sitemap-links" href="/responsabilidade/premio-literatura-infantil/">Prémio de Literatura Infantil</a>
#  <a class="sitemap-links" href="/responsabilidade/bairro-feliz/">Bairro Feliz</a>
#  <a class="sitemap-links" href="/responsabilidade/dieta-mediterranica/">Dieta Mediterrânica</a>
#  <a class="sitemap-links" href="https://menossalportugal.pt/" target="_blank">Menos Sal Portugal</a>
#  <a class="sitemap-links" href="/responsabilidade/amar-o-mar/">Amar o Mar</a>
#  <a class="sitemap-links" href="/responsabilidade/ecodesign-embalagens/">Ecodesign</a>
#  </div>
#  </div>
#  </div>,
#  <div class="first-level">
#  <a class="title hidden-mobile" href="/lojas/">Lojas</a>
#  <span class="title hidden-desktop">Lojas</span>
#  <div class="second-level">
#  <a class="sitemap-links" href="/servicos-loja/restaurante/">Restaurante</a>
#  <a class="sitemap-links" href="/servicos-loja/cafe-e-bolos/">Café e Bolos</a>
#  <a class="sitemap-links" href="/servicos-loja/bemestar-saude-e-beleza/">Bem Estar</a>
#  <a class="sitemap-links" href="/servicos-loja/code-vestuario/">Code</a>
#  <a class="sitemap-links" href="/servicos-loja/postos-de-combustivel/">Postos de Combustível</a>
#  </div>
#  </div>,
#  <div class="second-level">
#  <a class="sitemap-links" href="/servicos-loja/restaurante/">Restaurante</a>
#  <a class="sitemap-links" href="/servicos-loja/cafe-e-bolos/">Café e Bolos</a>
#  <a class="sitemap-links" href="/servicos-loja/bemestar-saude-e-beleza/">Bem Estar</a>
#  <a class="sitemap-links" href="/servicos-loja/code-vestuario/">Code</a>
#  <a class="sitemap-links" href="/servicos-loja/postos-de-combustivel/">Postos de Combustível</a>
#  </div>,
#  <div class="first-level">
#  <a class="title hidden-mobile" href="/lojas/">Serviços</a>
#  <span class="title hidden-desktop">Serviços</span>
#  <div class="second-level">
#  <a class="sitemap-links" href="/servicos-loja/entregas-ao-domicilio/">Entregas ao Domicílio</a>
#  <a class="sitemap-links" href="/produtos/take-away/encomendas/">Encomendas Take Away</a>
#  <a class="sitemap-links" href="/servicos-loja/agua-filtrada-eco/">Água Filtrada ECO</a>
#  <a class="sitemap-links" href="/lojas/?servicos=ecoponto-pilhas">Ecopontos</a>
#  </div>
#  </div>,
#  <div class="second-level">
#  <a class="sitemap-links" href="/servicos-loja/entregas-ao-domicilio/">Entregas ao Domicílio</a>
#  <a class="sitemap-links" href="/produtos/take-away/encomendas/">Encomendas Take Away</a>
#  <a class="sitemap-links" href="/servicos-loja/agua-filtrada-eco/">Água Filtrada ECO</a>
#  <a class="sitemap-links" href="/lojas/?servicos=ecoponto-pilhas">Ecopontos</a>
#  </div>,
#  <div class="first-level">
#  <a class="title hidden-mobile" href="/sobre-nos/">Sobre Nós</a>
#  <span class="title hidden-desktop">Sobre Nós</span>
#  <div class="second-level">
#  <a class="sitemap-links" href="/sobre-nos/noticias/">Notícias</a>
#  <a class="sitemap-links" href="/sobre-nos/cartao-poupa-mais/">Cartão Poupa Mais</a>
#  <a class="sitemap-links" href="/sobre-nos/cartao-presente-pingo-doce/">Cartão Presente</a>
#  <a class="sitemap-links" href="/sobre-nos/cartao-bom-pingo-doce/">Cartão Bom</a>
#  </div>
#  </div>,
#  <div class="second-level">
#  <a class="sitemap-links" href="/sobre-nos/noticias/">Notícias</a>
#  <a class="sitemap-links" href="/sobre-nos/cartao-poupa-mais/">Cartão Poupa Mais</a>
#  <a class="sitemap-links" href="/sobre-nos/cartao-presente-pingo-doce/">Cartão Presente</a>
#  <a class="sitemap-links" href="/sobre-nos/cartao-bom-pingo-doce/">Cartão Bom</a>
#  </div>,
#  <div class="first-level">
#  <a class="title hidden-mobile" href="/responsabilidade/">Responsabilidade</a>
#  <span class="title hidden-desktop">Responsabilidade</span>
#  <div class="second-level">
#  <span class="info">Áreas Prioritárias</span>
#  <a class="sitemap-links" href="/responsabilidade/#pilares-1">Saúde pela alimentação</a>
#  <a class="sitemap-links" href="/responsabilidade/#pilares-2">Biodiversidade</a>
#  <a class="sitemap-links" href="/responsabilidade/#pilares-3">Pessoas</a>
#  <a class="sitemap-links" href="/responsabilidade/#pilares-4">Literacia infanto-juvenil</a>
#  <a class="sitemap-links" href="/responsabilidade/#pilares-5">Ser solidário</a>
#  <span class="info hidden-desktop">Iniciativas</span>
#  <a class="sitemap-links hide-desktop" href="/responsabilidade/premio-literatura-infantil/">Prémio de Literatura Infantil</a>
#  <a class="sitemap-links hide-desktop" href="/responsabilidade/bairro-feliz/">Bairro Feliz</a>
#  <a class="sitemap-links hide-desktop" href="/responsabilidade/dieta-mediterranica/">Dieta Mediterrânica</a>
#  <a class="sitemap-links hide-desktop" href="https://menossalportugal.pt/" target="_blank">Menos Sal Portugal</a>
#  <a class="sitemap-links hide-desktop" href="/responsabilidade/amar-o-mar/">Amar o Mar</a>
#  <a class="sitemap-links hide-desktop" href="/responsabilidade/ecodesign-embalagens/">Ecodesign</a>
#  </div>
#  </div>,
#  <div class="second-level">
#  <span class="info">Áreas Prioritárias</span>
#  <a class="sitemap-links" href="/responsabilidade/#pilares-1">Saúde pela alimentação</a>
#  <a class="sitemap-links" href="/responsabilidade/#pilares-2">Biodiversidade</a>
#  <a class="sitemap-links" href="/responsabilidade/#pilares-3">Pessoas</a>
#  <a class="sitemap-links" href="/responsabilidade/#pilares-4">Literacia infanto-juvenil</a>
#  <a class="sitemap-links" href="/responsabilidade/#pilares-5">Ser solidário</a>
#  <span class="info hidden-desktop">Iniciativas</span>
#  <a class="sitemap-links hide-desktop" href="/responsabilidade/premio-literatura-infantil/">Prémio de Literatura Infantil</a>
#  <a class="sitemap-links hide-desktop" href="/responsabilidade/bairro-feliz/">Bairro Feliz</a>
#  <a class="sitemap-links hide-desktop" href="/responsabilidade/dieta-mediterranica/">Dieta Mediterrânica</a>
#  <a class="sitemap-links hide-desktop" href="https://menossalportugal.pt/" target="_blank">Menos Sal Portugal</a>
#  <a class="sitemap-links hide-desktop" href="/responsabilidade/amar-o-mar/">Amar o Mar</a>
#  <a class="sitemap-links hide-desktop" href="/responsabilidade/ecodesign-embalagens/">Ecodesign</a>
#  </div>,
#  <div class="first-level hide-mobile">
#  <div class="second-level extra-paddingtop">
#  <span class="info">Iniciativas</span>
#  <a class="sitemap-links" href="/responsabilidade/premio-literatura-infantil/">Prémio de Literatura Infantil</a>
#  <a class="sitemap-links" href="/responsabilidade/bairro-feliz/">Bairro Feliz</a>
#  <a class="sitemap-links" href="/responsabilidade/dieta-mediterranica/">Dieta Mediterrânica</a>
#  <a class="sitemap-links" href="https://menossalportugal.pt/" target="_blank">Menos Sal Portugal</a>
#  <a class="sitemap-links" href="/responsabilidade/amar-o-mar/">Amar o Mar</a>
#  <a class="sitemap-links" href="/responsabilidade/ecodesign-embalagens/">Ecodesign</a>
#  </div>
#  </div>,
#  <div class="second-level extra-paddingtop">
#  <span class="info">Iniciativas</span>
#  <a class="sitemap-links" href="/responsabilidade/premio-literatura-infantil/">Prémio de Literatura Infantil</a>
#  <a class="sitemap-links" href="/responsabilidade/bairro-feliz/">Bairro Feliz</a>
#  <a class="sitemap-links" href="/responsabilidade/dieta-mediterranica/">Dieta Mediterrânica</a>
#  <a class="sitemap-links" href="https://menossalportugal.pt/" target="_blank">Menos Sal Portugal</a>
#  <a class="sitemap-links" href="/responsabilidade/amar-o-mar/">Amar o Mar</a>
#  <a class="sitemap-links" href="/responsabilidade/ecodesign-embalagens/">Ecodesign</a>
#  </div>,
#  <div class="level-group">
#  <div class="first-level">
#  <a class="title hidden-mobile" href="/apoio-ao-cliente/">Ajuda</a>
#  <span class="title hidden-desktop">Ajuda</span>
#  <div class="second-level">
#  <a class="sitemap-links" href="/apoio-ao-cliente/#contactos">Contactos</a>
#  <a class="sitemap-links" href="/apoio-ao-cliente/perguntas-frequentes/">Perguntas Frequentes</a>
#  </div>
#  <a class="title hidden-mobile" href="/covid-19/" style="margin-top: 30px">Covid-19</a>
#  </div>
#  <div class="first-level hidden-desktop">
#  <a class="title covid-sitemap" href="/covid-19/">Covid-19</a>
#  </div>
#  <div class="first-level">
#  <a class="title hidden-mobile" href="/junte-se-a-nos/">Junte-se a Nós</a>
#  <span class="title hidden-desktop">Junte-se a Nós</span>
#  <div class="second-level">
#  <a class="sitemap-links" href="/junte-se-a-nos/">Recrutamento</a>
#  <a class="sitemap-links" href="/junte-se-a-nos/oportunidades/">Oportunidades</a>
#  <a class="sitemap-links" href="/junte-se-a-nos/">Candidatura Espontânea</a>
#  <a class="sitemap-links" href="/junte-se-a-nos/perguntas-respostas/">Perguntas e Respostas</a>
#  </div>
#  </div>
#  <div class="first-level">
#  <span class="title gray">Links Externos</span>
#  <div class="second-level">
#  <a class="sitemap-links" href="https://www.jeronimomartins.com/pt/" target="_blank">Grupo Jerónimo Martins</a>
#  <a class="sitemap-links" href="https://www.be-the-story.com/pt" target="_blank">Be The Story</a>
#  <a class="sitemap-links" href="https://mercadao.pt/store/pingo-doce" target="_blank">Mercadão</a>
#  <a class="sitemap-links" href="https://www.poupamais.pt/" target="_blank">Cartão Poupa Mais</a>
#  </div>
#  </div>
#  </div>,
#  <div class="first-level">
#  <a class="title hidden-mobile" href="/apoio-ao-cliente/">Ajuda</a>
#  <span class="title hidden-desktop">Ajuda</span>
#  <div class="second-level">
#  <a class="sitemap-links" href="/apoio-ao-cliente/#contactos">Contactos</a>
#  <a class="sitemap-links" href="/apoio-ao-cliente/perguntas-frequentes/">Perguntas Frequentes</a>
#  </div>
#  <a class="title hidden-mobile" href="/covid-19/" style="margin-top: 30px">Covid-19</a>
#  </div>,
#  <div class="second-level">
#  <a class="sitemap-links" href="/apoio-ao-cliente/#contactos">Contactos</a>
#  <a class="sitemap-links" href="/apoio-ao-cliente/perguntas-frequentes/">Perguntas Frequentes</a>
#  </div>,
#  <div class="first-level hidden-desktop">
#  <a class="title covid-sitemap" href="/covid-19/">Covid-19</a>
#  </div>,
#  <div class="first-level">
#  <a class="title hidden-mobile" href="/junte-se-a-nos/">Junte-se a Nós</a>
#  <span class="title hidden-desktop">Junte-se a Nós</span>
#  <div class="second-level">
#  <a class="sitemap-links" href="/junte-se-a-nos/">Recrutamento</a>
#  <a class="sitemap-links" href="/junte-se-a-nos/oportunidades/">Oportunidades</a>
#  <a class="sitemap-links" href="/junte-se-a-nos/">Candidatura Espontânea</a>
#  <a class="sitemap-links" href="/junte-se-a-nos/perguntas-respostas/">Perguntas e Respostas</a>
#  </div>
#  </div>,
#  <div class="second-level">
#  <a class="sitemap-links" href="/junte-se-a-nos/">Recrutamento</a>
#  <a class="sitemap-links" href="/junte-se-a-nos/oportunidades/">Oportunidades</a>
#  <a class="sitemap-links" href="/junte-se-a-nos/">Candidatura Espontânea</a>
#  <a class="sitemap-links" href="/junte-se-a-nos/perguntas-respostas/">Perguntas e Respostas</a>
#  </div>,
#  <div class="first-level">
#  <span class="title gray">Links Externos</span>
#  <div class="second-level">
#  <a class="sitemap-links" href="https://www.jeronimomartins.com/pt/" target="_blank">Grupo Jerónimo Martins</a>
#  <a class="sitemap-links" href="https://www.be-the-story.com/pt" target="_blank">Be The Story</a>
#  <a class="sitemap-links" href="https://mercadao.pt/store/pingo-doce" target="_blank">Mercadão</a>
#  <a class="sitemap-links" href="https://www.poupamais.pt/" target="_blank">Cartão Poupa Mais</a>
#  </div>
#  </div>,
#  <div class="second-level">
#  <a class="sitemap-links" href="https://www.jeronimomartins.com/pt/" target="_blank">Grupo Jerónimo Martins</a>
#  <a class="sitemap-links" href="https://www.be-the-story.com/pt" target="_blank">Be The Story</a>
#  <a class="sitemap-links" href="https://mercadao.pt/store/pingo-doce" target="_blank">Mercadão</a>
#  <a class="sitemap-links" href="https://www.poupamais.pt/" target="_blank">Cartão Poupa Mais</a>
#  </div>]
