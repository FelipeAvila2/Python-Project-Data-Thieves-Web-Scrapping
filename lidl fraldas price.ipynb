# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

# %%
# This is the url you will scrape in this exercise
url = 'https://www.lidl.pt/c/produtos-lupilu/c471'

# %%
# your code here
response = requests.get(url)
response
# Out:
# <Response [200]>

# %%
response.content
# Out:
# b'\n<!DOCTYPE html>\n<!--[if IEMobile 7 ]>\n<html lang="pt-PT" class="no-js iem7"></html><![endif]-->\n<!--[if lt IE 7 ]>\n<html lang="pt-PT" class="no-js ie6"></html><![endif]-->\n<!--[if IE 7 ]>\n<html lang="pt-PT" class="no-js ie7"></html><![endif]-->\n<!--[if IE 8 ]>\n<html lang="pt-PT" class="no-js ie8"></html><![endif]-->\n<!--[if IE 9 ]>\n<html lang="pt-PT" class="no-js ie9"></html><![endif]-->\n<!--[if (gte IE 11)|(gt IEMobile 7)|!(IEMobile)|!(IE)]><!-->\n<html lang="pt-PT" class="no-js">\n<!--<![endif]-->\n\n<head>\n\n\n            \n                        <!-- Cookiebot boot -->\n            <script id="Cookiebot" data-culture="pt" src="https://consent.cookiebot.com/uc.js" data-cbid="87e2eb41-6d23-4a66-8bcf-f85159ca77a7" data-blockingmode="auto" type="text/javascript"></script>\n            <!-- End cookiebot -->\n                    \n                    <!-- Start google Tag Manager -->\n                                                                <script>var dataLaye
# ...

# %%
soup = BeautifulSoup(response.content)

# %%
soup.text
# Out:
# '\n\n\n\n\n\n\n\n \n\n\n\n\n\n\nLupilu - www.lidl.pt\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\nNo Javascript\n\n\n\n\nNo Javascript\n\nPor favor active o Javascript\n                \n\n\n\n\n\n\nVá diretamente para\n\n\n\n                                    Menu\n                        \n\n\n\n                                    Serviços\n                        \n\n\n\n                                    jumpmark.item.textblock.content\n                        \n\n\n\n                                    Seleção de Língua\n                        \n\n\n\n                                    Seleção de Língua\n                        \n\n\n\n\n\n\n\n\n\n\n\n\n\n\nFechar\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n        Lidl\n    \n\n\n\nNavegação da empresa\n\n\n\n\n\n\n                                            Sustentabilidade\n                                    \n\n\n\n\n\n                                            Sobre Nós\n                              
# ...

# %%
k = requests.get('https://www.lidl.pt/c/produtos-lupilu/c471').text
soup=BeautifulSoup(k,'html.parser')
productlist = soup.find_all("h3")
print(productlist)
# Out:
# [<h3 class="product__title" data-clamp="data-clamp">
#                     Lupilu® Puré de Fruta Bio Banana e Maçã / Maçã Pêssego Banana
#                     <sup class="product__superscript">
# </sup>
# </h3>, <h3 class="product__title" data-clamp="data-clamp">
#                     Lupilu® Bolsa Fruta Bio Maçã/Pera/Morango
#                     <sup class="product__superscript">
# </sup>
# </h3>, <h3 class="product__title" data-clamp="data-clamp">
#                     Lupilu® Refeições Bio de Peru Arroz Legumes
#                     <sup class="product__superscript">
# </sup>
# </h3>, <h3 class="product__title" data-clamp="data-clamp">
#                     Lupilu® Refeições Bio Peru Legumes e Batata
#                     <sup class="product__superscript">
# </sup>
# </h3>, <h3 class="product__title" data-clamp="data-clamp">
#                     Lupilu® Barra de Fruta Bio
#                     <sup class="product__superscript">
# </sup>
# ...

# %%
k = requests.get('https://www.lidl.pt/c/produtos-lupilu/c471').text
soup=BeautifulSoup(k,'html.parser')
productlist = soup.find_all("div", attrs = {'class':'attributebox'})
print(productlist)
# Out:
# []

# %%
print(type(productlist))
# Out:
# <class 'bs4.element.ResultSet'>

# %%
k = requests.get('https://www.lidl.pt/c/produtos-lupilu/c471').text
soup=BeautifulSoup(k,'html.parser')
productlist = soup.find_all("span")
print(productlist)
# Out:
# [<span class="hint__icon-container">
# <span class="icon icon--danger icon--no-pointer-events icon--small icon--medium@md">
# <svg role="img">
# <title>No Javascript</title>
# <use xlink:href="/bundles/cakecomponents/dist/images/icon__sprite.svg#danger"></use>
# </svg>
# </span>
# </span>, <span class="icon icon--danger icon--no-pointer-events icon--small icon--medium@md">
# <svg role="img">
# <title>No Javascript</title>
# <use xlink:href="/bundles/cakecomponents/dist/images/icon__sprite.svg#danger"></use>
# </svg>
# </span>, <span class="icon icon--x icon--small" data-controller="notice/close-button/icon" focusable="false" tabindex="-1">
# <svg focusable="false" role="img">
# <title>Fechar</title>
# <!-- c -->
# <use xlink:href="/bundles/cakecomponents/dist/images/icon__sprite.svg#x"></use>
# <!-- c -->
# </svg>
# </span>, <span class="navigation__text navigation__text--center">
#                                             Sustentabilidade
# ...

# %%
k = requests.get('https://www.lidl.pt/c/produtos-lupilu/c471').text
soup=BeautifulSoup(k,'html.parser')
productlist = soup.find_all(attrs ={'class':'pricebox__price'})
#print(productlist)
print(productlist[0])
# Out:
# <span class="pricebox__price">
#                         1.19
#                     </span>

# %%
for element in productlist:
  print(element.text)  
print(type(element.text)) 
price = element.text
# Out:
#                         1.19
#
#
#                         0.69
#
#
#                         1.29
#
#
#                         1.29
#
#
#                         0.49
#
#
#                         1.59
#
#
#                         1.79
#
#
#                         1.79
#
#
#                         1.09
#
#
#                         1.39
#
#
#                         1.25
#
#
#                         2.29
#
#
#                         3.59
#
#
#                         2.79
#
#
#                         4.45
#
#
#                         5.79
#
#
#                         5.79
#
#
#                         5.79
#
#
#                         5.15
#
#
#                         3.99
#
#
#                         3.99
#
#
#                         3.99
#
# <class 'str'>

# %%
for element in productlist[0]:
  print(element)
# Out:
#                         1.19

# %%
price =element
type(price)
# Out:
# bs4.element.NavigableString

# %%
price_fraldas_lidl = float(price)

# %%
type(price)
# Out:
# bs4.element.NavigableString

# %%
k = requests.get('https://www.lidl.pt/c/produtos-lupilu/c471').text
soup=BeautifulSoup(k,'html.parser')
productlist = soup.find_all('h3', attrs= { 'class:','product__title'})

# %%
productlist
# Out:
# [<h3 class="product__title" data-clamp="data-clamp">
#                      Lupilu® Puré de Fruta Bio Banana e Maçã / Maçã Pêssego Banana
#                      <sup class="product__superscript">
#  </sup>
#  </h3>,
#  <h3 class="product__title" data-clamp="data-clamp">
#                      Lupilu® Bolsa Fruta Bio Maçã/Pera/Morango
#                      <sup class="product__superscript">
#  </sup>
#  </h3>,
#  <h3 class="product__title" data-clamp="data-clamp">
#                      Lupilu® Refeições Bio de Peru Arroz Legumes
#                      <sup class="product__superscript">
#  </sup>
#  </h3>,
#  <h3 class="product__title" data-clamp="data-clamp">
#                      Lupilu® Refeições Bio Peru Legumes e Batata
#                      <sup class="product__superscript">
#  </sup>
#  </h3>,
#  <h3 class="product__title" data-clamp="data-clamp">
#                      Lupilu® Barra de Fruta Bio
#                      <sup class="product__superscript">
#  </sup>
#  </h3>,
# ...

# %%
productlist
# Out:
# [<h3 class="product__title" data-clamp="data-clamp">
#                      Lupilu® Puré de Fruta Bio Banana e Maçã / Maçã Pêssego Banana
#                      <sup class="product__superscript">
#  </sup>
#  </h3>,
#  <h3 class="product__title" data-clamp="data-clamp">
#                      Lupilu® Bolsa Fruta Bio Maçã/Pera/Morango
#                      <sup class="product__superscript">
#  </sup>
#  </h3>,
#  <h3 class="product__title" data-clamp="data-clamp">
#                      Lupilu® Refeições Bio de Peru Arroz Legumes
#                      <sup class="product__superscript">
#  </sup>
#  </h3>,
#  <h3 class="product__title" data-clamp="data-clamp">
#                      Lupilu® Refeições Bio Peru Legumes e Batata
#                      <sup class="product__superscript">
#  </sup>
#  </h3>,
#  <h3 class="product__title" data-clamp="data-clamp">
#                      Lupilu® Barra de Fruta Bio
#                      <sup class="product__superscript">
#  </sup>
#  </h3>,
# ...

# %%
list_items = []
for element in productlist:
  print(element.text)
  list_items.append(element.text)
print(type(element.text)) 
price = element.text
# Out:
#                     Lupilu® Puré de Fruta Bio Banana e Maçã / Maçã Pêssego Banana
#
#
#
#
#                     Lupilu® Bolsa Fruta Bio Maçã/Pera/Morango
#
#
#
#
#                     Lupilu® Refeições Bio de Peru Arroz Legumes
#
#
#
#
#                     Lupilu® Refeições Bio Peru Legumes e Batata
#
#
#
#
#                     Lupilu® Barra de Fruta Bio
#
#
#
#
#                     Lupilu® Óleo Corporal
#
#
#
#
#                     Lupilu® Champô Infantil
#
#
#
#
#                     Lupilu® Espuma  de Banho
#
#
#
#
#                     Lupilu® Toalhitas para Bebé com Tampa
#
#
#
#
#                     Lupilu® Toalhitas para Rosto e Mãos
#
#
#
#
#                     Lupilu® Creme Muda Fraldas
#
#
#
#
#                     Lupilu® Mudafraldas
#
#
#
#
#                     Lupilu® Resguardo para Cama de Bebé
#
#
#
#
#                     Lupilu® Fraldas Tamanho 1
#
#
#
#
#                     Lupilu® Fraldas Tamanho 2
#
#
#
#
#                     Lupilu® Fraldas Tamanho 3
#
# ...

# %%
str = ""
price = list(price)
fraldas_name = str.join(price).strip()
fraldas_name
# Out:
# 'Lupilu® Fraldas Cueca Tamanho 6'

# %%
print(list_items)
# Out:
# ['\n                    Lupilu® Puré de Fruta Bio Banana e Maçã / Maçã Pêssego Banana\n                    \n\n', '\n                    Lupilu® Bolsa Fruta Bio Maçã/Pera/Morango\n                    \n\n', '\n                    Lupilu® Refeições Bio de Peru Arroz Legumes\n                    \n\n', '\n                    Lupilu® Refeições Bio Peru Legumes e Batata\n                    \n\n', '\n                    Lupilu® Barra de Fruta Bio\n                    \n\n', '\n                    Lupilu® Óleo Corporal\n                    \n\n', '\n                    Lupilu® Champô Infantil\n                    \n\n', '\n                    Lupilu® Espuma  de Banho \n                    \n\n', '\n                    Lupilu® Toalhitas para Bebé com Tampa\n                    \n\n', '\n                    Lupilu® Toalhitas para Rosto e Mãos\n                    \n\n', '\n                    Lupilu® Creme Muda Fraldas \n                    \n\n', '\n                    Lupilu® Mudafraldas\
# ...

# %%
list_espaco = []
for item in list_items:
    
    list_espaco.append(item.replace("\n","").strip())
print(list_espaco)
# Out:
# ['Lupilu® Puré de Fruta Bio Banana e Maçã / Maçã Pêssego Banana', 'Lupilu® Bolsa Fruta Bio Maçã/Pera/Morango', 'Lupilu® Refeições Bio de Peru Arroz Legumes', 'Lupilu® Refeições Bio Peru Legumes e Batata', 'Lupilu® Barra de Fruta Bio', 'Lupilu® Óleo Corporal', 'Lupilu® Champô Infantil', 'Lupilu® Espuma  de Banho', 'Lupilu® Toalhitas para Bebé com Tampa', 'Lupilu® Toalhitas para Rosto e Mãos', 'Lupilu® Creme Muda Fraldas', 'Lupilu® Mudafraldas', 'Lupilu® Resguardo para Cama de Bebé', 'Lupilu® Fraldas Tamanho 1', 'Lupilu® Fraldas Tamanho 2', 'Lupilu® Fraldas Tamanho 3', 'Lupilu® Fraldas Tamanho 4', 'Lupilu® Fraldas Tamanho 5', 'Lupilu® Fraldas Tamanho 6', 'Lupilu® Fralda Cueca Tamanho 4', 'Lupilu® Fraldas Cueca Tamanho 5', 'Lupilu® Fraldas Cueca Tamanho 6']

# %%
list_espaco
# Out:
# ['Lupilu® Puré de Fruta Bio Banana e Maçã / Maçã Pêssego Banana',
#  'Lupilu® Bolsa Fruta Bio Maçã/Pera/Morango',
#  'Lupilu® Refeições Bio de Peru Arroz Legumes',
#  'Lupilu® Refeições Bio Peru Legumes e Batata',
#  'Lupilu® Barra de Fruta Bio',
#  'Lupilu® Óleo Corporal',
#  'Lupilu® Champô Infantil',
#  'Lupilu® Espuma  de Banho',
#  'Lupilu® Toalhitas para Bebé com Tampa',
#  'Lupilu® Toalhitas para Rosto e Mãos',
#  'Lupilu® Creme Muda Fraldas',
#  'Lupilu® Mudafraldas',
#  'Lupilu® Resguardo para Cama de Bebé',
#  'Lupilu® Fraldas Tamanho 1',
#  'Lupilu® Fraldas Tamanho 2',
#  'Lupilu® Fraldas Tamanho 3',
#  'Lupilu® Fraldas Tamanho 4',
#  'Lupilu® Fraldas Tamanho 5',
#  'Lupilu® Fraldas Tamanho 6',
#  'Lupilu® Fralda Cueca Tamanho 4',
#  'Lupilu® Fraldas Cueca Tamanho 5',
#  'Lupilu® Fraldas Cueca Tamanho 6']
